# %% [markdown]
# # Inter-Rater Reliability Analysis - ITERATION 2
#
# **After Re-calibration Discussion**
#
# Analyzing agreement for iteration2 labels (users 3, 5, 6, 7)

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import cohen_kappa_score, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
