# %% [markdown]
# # Quick CNN Training - Ultra Lightweight + Augmentation
# ## Streamlined version for rapid iteration
#
# This notebook contains only the essential components for training the ultra-lightweight CNN with augmentation and random shuffle split.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, roc_auc_score
from sklearn.preprocessing import label_binarize
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
from tensorflow.keras.utils import to_categorical
import warnings
warnings.filterwarnings('ignore')

print(f"TensorFlow version: {tf.__version__}")
print(f"Keras version: {keras.__version__}")
# Out:
# TensorFlow version: 2.20.0
# Keras version: 3.11.3

# %%
# CONFIG
df_sensor = pd.read_csv('./data/final_dataset.csv')
df_windows = pd.read_csv('./data/final_window_labels.csv') 

concept_columns = {'periodicity', 'temporal_stability', 'coordination', 'motion_intensity', 'vertical_dominance'}
discrete_concepts = {'periodicity', 'temporal_stability', 'coordination'}
continuous_concepts = {'motion_intensity', 'vertical_dominance'}

# %%
print(f"Sensor data: {len(df_sensor)} readings")
print(f"Manual labels: {len(df_windows)} windows")
print(f"\nLabeled windows:")
print(df_windows.head())

print(f"\nAvailable concepts: {concept_columns}")
print(f"\nConcept distributions:")

for concept in concept_columns:
    if concept not in df_windows.columns:
        print(f"  {concept}: (missing from data)")
        continue

    if concept in discrete_concepts:
        print(f"\n  [Discrete] {concept}:")
        print(df_windows[concept].value_counts(dropna=False))
    elif concept in continuous_concepts:
        print(f"\n  [Continuous] {concept}:")
        print(df_windows[concept].describe())
    else:
        print(f"\n  [Unknown type] {concept}:")
        print(df_windows[concept].head())
# Out:
# Sensor data: 8802 readings
# Manual labels: 150 windows
#
# Labeled windows:
#    window_idx  user activity  start_time  end_time  periodicity  \
# 0           0     3  Walking      957.75    960.75          1.0
# 1           1     3  Walking       42.00     45.00          1.0
# 2           2     3  Walking      871.50    874.50          0.5
# 3           3     3  Walking       63.00     66.00          1.0
# 4           4     3  Jogging      117.75    120.75          1.0
#
#    temporal_stability  coordination  motion_intensity  vertical_dominance
# 0                 0.5           0.5          0.316815            0.221105
# 1                 0.5           0.5          0.302850            0.291116
# 2                 0.5           0.5          0.303036            0.181147
# 3                 0.5           0.5          0.313779            0.305797
# 4                 0.5           0.5          0.408648            0.262989
#
# Available concepts: {'temporal_stability', 'periodicity', 'coordination', 'vertical_dominance', 'motion_intensity'}
#
# Concept distributions:
#
#   [Discrete] temporal_stability:
# temporal_stability
# 0.5    87
# 1.0    51
# 0.0    12
# Name: count, dtype: int64
#
#   [Discrete] periodicity:
# periodicity
# 0.0    90
# 0.5    35
# 1.0    25
# Name: count, dtype: int64
#
#   [Discrete] coordination:
# coordination
# 1.0    70
# 0.5    64
# 0.0    16
# Name: count, dtype: int64
#
#   [Continuous] vertical_dominance:
# count    150.000000
# mean       0.248287
# std        0.080944
# min        0.041401
# 25%        0.201228
# 50%        0.236932
# 75%        0.291116
# max        0.562017
# Name: vertical_dominance, dtype: float64
#
#   [Continuous] motion_intensity:
# count    150.000000
# mean       0.331157
# std        0.041124
# min        0.277237
# 25%        0.304296
# 50%        0.316702
# 75%        0.338431
# max        0.471138
# Name: motion_intensity, dtype: float64

# %%
def extract_window_robust(df_sensor, window_row, time_tolerance=0.5):
    """
    Extract sensor data with time tolerance to handle mismatches.
    """
    user = window_row['user']
    activity = window_row['activity']
    start_time = window_row['start_time']
    end_time = window_row['end_time']
    
    # Get data for this user/activity
    user_activity_data = df_sensor[(df_sensor['user'] == user) & 
                                  (df_sensor['activity'] == activity)].copy()
    
    if len(user_activity_data) == 0:
        return None
    
    # Find data within time window with tolerance
    mask = ((user_activity_data['time_s'] >= start_time - time_tolerance) & 
            (user_activity_data['time_s'] <= end_time + time_tolerance))
    
    window_data = user_activity_data[mask]
    
    if len(window_data) < 10:  # Need minimum samples
        return None
    
    # Extract sensor readings
    sensor_data = window_data[['x-axis', 'y-axis', 'z-axis']].values
    
    # Pad or truncate to fixed length (e.g., 100 samples)
    target_length = 60
    if len(sensor_data) > target_length:
        # Randomly sample if too long
        indices = np.random.choice(len(sensor_data), target_length, replace=False)
        sensor_data = sensor_data[indices]
    elif len(sensor_data) < target_length:
        # Pad with last value if too short
        padding = np.tile(sensor_data[-1:], (target_length - len(sensor_data), 1))
        sensor_data = np.vstack([sensor_data, padding])
    
    return sensor_data

def extract_windows_robust(df_sensor, df_windows):
    """
    Extract all windows with robust time matching for 6 concepts.
    """
    X = []
    y_p = []  # periodicity
    y_t = []  # temporal_stability
    y_c = []  # coordination
    y_mi = [] # motion_intensity
    y_vd = [] # vertical_dominance
    
    for _, window_row in df_windows.iterrows():
        window_data = extract_window_robust(df_sensor, window_row)
        if window_data is not None:
            X.append(window_data)
            y_p.append(window_row['periodicity'])
            y_t.append(window_row['temporal_stability'])
            y_c.append(window_row['coordination'])
            y_mi.append(window_row['motion_intensity'])
            y_vd.append(window_row['vertical_dominance'])
    
    return np.array(X), np.array(y_p), np.array(y_t), np.array(y_c), np.array(y_mi), np.array(y_vd)

# %%
def augment_jitter(data, sigma=0.05):
    """Add random Gaussian noise to simulate sensor imperfections"""
    return data + np.random.normal(0, sigma, data.shape)

def augment_scaling(data, sigma=0.1):
    """Scale magnitude to simulate different movement intensities"""
    # Handle different data shapes
    if len(data.shape) == 3:
        factor = np.random.normal(1.0, sigma, (data.shape[0], 1, data.shape[2]))
    elif len(data.shape) == 2:
        factor = np.random.normal(1.0, sigma, (data.shape[0], data.shape[1]))
    else:
        factor = np.random.normal(1.0, sigma, data.shape)
    return data * factor

def augment_rotation(data):
    """Rotate 3D data to simulate different phone orientations"""
    angle = np.random.uniform(-np.pi/6, np.pi/6)  # ±30 degrees
    cos_a, sin_a = np.cos(angle), np.sin(angle)
    rotation_matrix = np.array([
        [cos_a, -sin_a, 0],
        [sin_a, cos_a, 0],
        [0, 0, 1]
    ])
    return np.dot(data, rotation_matrix.T)

def augment_dataset(X, y_p, y_t, y_c, y_mi, y_vd, factor=10):
    """
    Create augmented versions of the dataset for 7 concepts.
    
    Args:
        X: Original data (n_samples, timesteps, 3)
        y_p, y_t, y_c, y_mi, y_vd, y_sp, y_mag: Labels for seven concepts
        factor: Augmentation multiplier (10 = 10x more data)
    
    Returns:
        Augmented dataset with (factor+1) × original size
    """
    n_original = len(X)
    n_augmented = n_original * factor
    
    # Initialize augmented arrays
    X_aug = np.zeros((n_augmented, X.shape[1], X.shape[2]))
    y_p_aug = np.zeros(n_augmented)
    y_t_aug = np.zeros(n_augmented)
    y_c_aug = np.zeros(n_augmented)
    y_mi_aug = np.zeros(n_augmented)
    y_vd_aug = np.zeros(n_augmented)
    
    for i in range(n_augmented):
        # Randomly select original sample
        idx = np.random.randint(0, n_original)
        
        # Apply random augmentation
        aug_type = np.random.choice(['jitter', 'scaling', 'rotation', 'none'])
        
        if aug_type == 'jitter':
            X_aug[i] = augment_jitter(X[idx])
        elif aug_type == 'scaling':
            X_aug[i] = augment_scaling(X[idx])
        elif aug_type == 'rotation':
            X_aug[i] = augment_rotation(X[idx])
        else:  # none
            X_aug[i] = X[idx]
        
        # Copy labels
        y_p_aug[i] = y_p[idx]
        y_t_aug[i] = y_t[idx]
        y_c_aug[i] = y_c[idx]
        y_mi_aug[i] = y_mi[idx]
        y_vd_aug[i] = y_vd[idx]
    
    # Combine original and augmented data
    X_combined = np.vstack([X, X_aug])
    y_p_combined = np.concatenate([y_p, y_p_aug])
    y_t_combined = np.concatenate([y_t, y_t_aug])
    y_c_combined = np.concatenate([y_c, y_c_aug])
    y_mi_combined = np.concatenate([y_mi, y_mi_aug])
    y_vd_combined = np.concatenate([y_vd, y_vd_aug])
    
    return X_combined, y_p_combined, y_t_combined, y_c_combined, y_mi_combined, y_vd_combined

# %%
def build_optimized_cnn(input_shape, n_classes_p, n_classes_t, n_classes_c):
    input_layer = layers.Input(shape=input_shape)
    
    x = layers.Conv1D(16, 3, activation='relu', padding='same')(input_layer)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling1D(2)(x)
    
    x = layers.Conv1D(16, 3, activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.GlobalAveragePooling1D()(x)
    
    x = layers.Dropout(0.4)(x)
    
    # Discrete concepts
    periodicity = layers.Dense(n_classes_p, activation='softmax', name='periodicity')(x)
    temporal_stability = layers.Dense(n_classes_t, activation='softmax', name='temporal_stability')(x)
    coordination = layers.Dense(n_classes_c, activation='softmax', name='coordination')(x)
    
    # Continuous concepts
    motion_intensity = layers.Dense(1, activation='linear', name='motion_intensity')(x)
    vertical_dominance = layers.Dense(1, activation='linear', name='vertical_dominance')(x)
    
    model = models.Model(inputs=input_layer, outputs=[periodicity, temporal_stability, coordination, motion_intensity, vertical_dominance])
    
    return model

# %%
print("Extracting windows...")
X, y_p, y_t, y_c, y_mi, y_vd = extract_windows_robust(df_sensor, df_windows)

print(f"Extracted {len(X)} windows")
print(f"Window shape: {X.shape}")
print(f"Label distributions:")
print(f"  Periodicity: {np.bincount(y_p.astype(int))}")
print(f"  Temporal Stability: {np.bincount(y_t.astype(int))}")
print(f"  Coordination: {np.bincount(y_c.astype(int))}")
print(f"  Motion Intensity: {np.bincount(y_mi.astype(int))}")
print(f"  Vertical Dominance: {np.bincount(y_vd.astype(int))}")
# Out:
# Extracting windows...
# Extracted 150 windows
# Window shape: (150, 60, 3)
# Label distributions:
#   Periodicity: [125  25]
#   Temporal Stability: [99 51]
#   Coordination: [80 70]
#   Motion Intensity: [150]
#   Vertical Dominance: [150]

# %%
print("Splitting data...")
X_train, X_test, y_p_train, y_p_test, y_t_train, y_t_test, y_c_train, y_c_test, y_mi_train, y_mi_test, y_vd_train, y_vd_test = train_test_split(
    X, y_p, y_t, y_c, y_mi, y_vd, test_size=0.25, random_state=42, stratify=None
)

print(f"Train: {len(X_train)} windows")
print(f"Test: {len(X_test)} windows")
# Out:
# Splitting data...
# Train: 112 windows
# Test: 38 windows

# %%
print("Augmenting training data...")
X_train_aug, y_p_train_aug, y_t_train_aug, y_c_train_aug, y_mi_train_aug, y_vd_train_aug = augment_dataset(
    X_train, y_p_train, y_t_train, y_c_train, y_mi_train, y_vd_train, factor=10
)

print(f"Original train: {len(X_train)} windows")
print(f"Augmented train: {len(X_train_aug)} windows")
print(f"Augmentation factor: {len(X_train_aug) / len(X_train):.1f}x")
# Out:
# Augmenting training data...
# Original train: 112 windows
# Augmented train: 1232 windows
# Augmentation factor: 11.0x

# %%
# Convert labels to categorical
# Discrete
y_p_train_cat = to_categorical(y_p_train_aug * 2, num_classes=3)
y_t_train_cat = to_categorical(y_t_train_aug * 2, num_classes=3)
y_c_train_cat = to_categorical(y_c_train_aug * 2, num_classes=3)

# Continous
y_mi_train_cat = y_mi_train_aug.astype(np.float32).reshape(-1, 1)
y_vd_train_cat = y_vd_train_aug.astype(np.float32).reshape(-1, 1)

# Discrete
y_p_test_cat = to_categorical(y_p_test * 2, num_classes=3)
y_t_test_cat = to_categorical(y_t_test * 2, num_classes=3)
y_c_test_cat = to_categorical(y_c_test * 2, num_classes=3)

# Continous
y_mi_test_cat = y_mi_test.astype(np.float32).reshape(-1, 1)
y_vd_test_cat = y_vd_test.astype(np.float32).reshape(-1, 1)

print("Labels converted to categorical format")
# Out:
# Labels converted to categorical format

# %%
print("Building model...")
model = build_optimized_cnn(
    input_shape=(X_train_aug.shape[1], X_train_aug.shape[2]),
    n_classes_p=3, n_classes_t=3, n_classes_c=3
)

# Compile with appropriate loss weights
model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=0.001),
        loss={
            'periodicity': 'categorical_crossentropy',
            'temporal_stability': 'categorical_crossentropy',
            'coordination': 'categorical_crossentropy',
            'motion_intensity': 'mse',
            'vertical_dominance': 'mse'
        },
        loss_weights={
            'periodicity': 1.0,
            'temporal_stability': 1.0,
            'coordination': 1.0,
            'motion_intensity': 1.0,
            'vertical_dominance': 1.0
        },
        metrics={
            'periodicity': ['accuracy'],
            'temporal_stability': ['accuracy'],
            'coordination': ['accuracy'],
            'motion_intensity': ['mse'],
            'vertical_dominance': ['mse']
        }
    )
    

print(f"Model parameters: {model.count_params():,}")
model.summary()
# Out:
# Building model...
# Model parameters: 1,259
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 60, 3)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_2 (Conv1D)   │ (None, 60, 16)    │        160 │ input_layer_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 60, 16)    │         64 │ conv1d_2[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_1     │ (None, 30, 16)    │          0 │ batch_normalizat… │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_3 (Conv1D)   │ (None, 30, 16)    │        784 │ max_pooling1d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 30, 16)    │         64 │ conv1d_3[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 16)        │          0 │ batch_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 16)        │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ periodicity (Dense) │ (None, 3)         │         51 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ temporal_stability  │ (None, 3)         │         51 │ dropout_1[0][0]   │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ coordination        │ (None, 3)         │         51 │ dropout_1[0][0]   │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ motion_intensity    │ (None, 1)         │         17 │ dropout_1[0][0]   │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ vertical_dominance  │ (None, 1)         │         17 │ dropout_1[0][0]   │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,259 (4.92 KB)
#  Trainable params: 1,195 (4.67 KB)
#  Non-trainable params: 64 (256.00 B)

# %%
print("Training model...")
history = model.fit(
    X_train_aug,
    [y_p_train_cat, y_t_train_cat, y_c_train_cat, y_mi_train_cat, y_vd_train_cat],
    validation_data=(X_test, [y_p_test_cat, y_t_test_cat, y_c_test_cat, y_mi_test_cat, y_vd_test_cat]),
    epochs=200,
    batch_size=32,
    verbose=1,
    callbacks=[
        keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True),
        keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=5)
    ]
)

print("Training completed!")
# Out:
# Training model...
# Epoch 1/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - coordination_accuracy: 0.3661 - coordination_loss: 1.4470 - loss: 5.1253 - motion_intensity_loss: 0.8293 - motion_intensity_mse: 0.8350 - periodicity_accuracy: 0.3807 - periodicity_loss: 1.2100 - temporal_stability_accuracy: 0.4886 - temporal_stability_loss: 1.0704 - vertical_dominance_loss: 0.5482 - vertical_dominance_mse: 0.5514 - val_coordination_accuracy: 0.2368 - val_coordination_loss: 2.1874 - val_loss: 5.4826 - val_motion_intensity_loss: 0.2445 - val_motion_intensity_mse: 0.2668 - val_periodicity_accuracy: 0.2895 - val_periodicity_loss: 1.7877 - val_temporal_stability_accuracy: 0.5000 - val_temporal_stability_loss: 0.8783 - val_vertical_dominance_loss: 0.0825 - val_vertical_dominance_mse: 0.1144 - learning_rate: 0.0010
# Epoch 2/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - coordination_accuracy: 0.4878 - coordination_loss: 1.0854 - loss: 3.8452 - motion_intensity_loss: 0.4231 - motion_intensity_mse: 0.4239 - periodicity_accuracy: 0.4724 - periodicity_loss: 1.0367 - temporal_stability_accuracy: 0.5739 - temporal_stability_loss: 0.9764 - vertical_dominance_loss: 0.3139 - vertical_dominance_mse: 0.3159 - val_coordination_accuracy: 0.3684 - val_coordination_loss: 1.5076 - val_loss: 3.9534 - val_motion_intensity_loss: 0.1035 - val_motion_intensity_mse: 0.1046 - val_periodicity_accuracy: 0.3684 - val_periodicity_loss: 1.1811 - val_temporal_stability_accuracy: 0.5263 - val_temporal_stability_loss: 0.8509 - val_vertical_dominance_loss: 0.0374 - val_vertical_dominance_mse: 0.0546 - learning_rate: 0.0010
# Epoch 3/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - coordination_accuracy: 0.5747 - coordination_loss: 0.9465 - loss: 3.2691 - motion_intensity_loss: 0.2878 - motion_intensity_mse: 0.2879 - periodicity_accuracy: 0.5601 - periodicity_loss: 0.9335 - temporal_stability_accuracy: 0.6429 - temporal_stability_loss: 0.8919 - vertical_dominance_loss: 0.2089 - vertical_dominance_mse: 0.2083 - val_coordination_accuracy: 0.4211 - val_coordination_loss: 1.1077 - val_loss: 3.1934 - val_motion_intensity_loss: 0.0650 - val_motion_intensity_mse: 0.0574 - val_periodicity_accuracy: 0.5000 - val_periodicity_loss: 0.8541 - val_temporal_stability_accuracy: 0.6316 - val_temporal_stability_loss: 0.7877 - val_vertical_dominance_loss: 0.0362 - val_vertical_dominance_mse: 0.0408 - learning_rate: 0.0010
# Epoch 4/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - coordination_accuracy: 0.6420 - coordination_loss: 0.8486 - loss: 2.9251 - motion_intensity_loss: 0.2082 - motion_intensity_mse: 0.2096 - periodicity_accuracy: 0.6023 - periodicity_loss: 0.8651 - temporal_stability_accuracy: 0.7094 - temporal_stability_loss: 0.8382 - vertical_dominance_loss: 0.1583 - vertical_dominance_mse: 0.1593 - val_coordination_accuracy: 0.5789 - val_coordination_loss: 0.9222 - val_loss: 2.8046 - val_motion_intensity_loss: 0.0348 - val_motion_intensity_mse: 0.0256 - val_periodicity_accuracy: 0.6579 - val_periodicity_loss: 0.7309 - val_temporal_stability_accuracy: 0.6842 - val_temporal_stability_loss: 0.7221 - val_vertical_dominance_loss: 0.0219 - val_vertical_dominance_mse: 0.0304 - learning_rate: 0.0010
# Epoch 5/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - coordination_accuracy: 0.6786 - coordination_loss: 0.8119 - loss: 2.7482 - motion_intensity_loss: 0.1799 - motion_intensity_mse: 0.1808 - periodicity_accuracy: 0.6315 - periodicity_loss: 0.8375 - temporal_stability_accuracy: 0.7630 - temporal_stability_loss: 0.7812 - vertical_dominance_loss: 0.1400 - vertical_dominance_mse: 0.1408 - val_coordination_accuracy: 0.6053 - val_coordination_loss: 0.8266 - val_loss: 2.6055 - val_motion_intensity_loss: 0.0245 - val_motion_intensity_mse: 0.0205 - val_periodicity_accuracy: 0.6053 - val_periodicity_loss: 0.6659 - val_temporal_stability_accuracy: 0.6842 - val_temporal_stability_loss: 0.6644 - val_vertical_dominance_loss: 0.0243 - val_vertical_dominance_mse: 0.0310 - learning_rate: 0.0010
# Epoch 6/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - coordination_accuracy: 0.7192 - coordination_loss: 0.7538 - loss: 2.5372 - motion_intensity_loss: 0.1426 - motion_intensity_mse: 0.1433 - periodicity_accuracy: 0.6396 - periodicity_loss: 0.8037 - temporal_stability_accuracy: 0.7873 - temporal_stability_loss: 0.7226 - vertical_dominance_loss: 0.1120 - vertical_dominance_mse: 0.1112 - val_coordination_accuracy: 0.6316 - val_coordination_loss: 0.7472 - val_loss: 2.4629 - val_motion_intensity_loss: 0.0234 - val_motion_intensity_mse: 0.0242 - val_periodicity_accuracy: 0.6316 - val_periodicity_loss: 0.6235 - val_temporal_stability_accuracy: 0.6842 - val_temporal_stability_loss: 0.6064 - val_vertical_dominance_loss: 0.0213 - val_vertical_dominance_mse: 0.0287 - learning_rate: 0.0010
# Epoch 7/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - coordination_accuracy: 0.7451 - coordination_loss: 0.7225 - loss: 2.4119 - motion_intensity_loss: 0.1275 - motion_intensity_mse: 0.1279 - periodicity_accuracy: 0.6664 - periodicity_loss: 0.7792 - temporal_stability_accuracy: 0.8109 - temporal_stability_loss: 0.6840 - vertical_dominance_loss: 0.0998 - vertical_dominance_mse: 0.0994 - val_coordination_accuracy: 0.6579 - val_coordination_loss: 0.7200 - val_loss: 2.3638 - val_motion_intensity_loss: 0.0202 - val_motion_intensity_mse: 0.0226 - val_periodicity_accuracy: 0.6316 - val_periodicity_loss: 0.5846 - val_temporal_stability_accuracy: 0.7105 - val_temporal_stability_loss: 0.5773 - val_vertical_dominance_loss: 0.0204 - val_vertical_dominance_mse: 0.0266 - learning_rate: 0.0010
# Epoch 8/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - coordination_accuracy: 0.7476 - coordination_loss: 0.6990 - loss: 2.3187 - motion_intensity_loss: 0.1158 - motion_intensity_mse: 0.1154 - periodicity_accuracy: 0.6640 - periodicity_loss: 0.7747 - temporal_stability_accuracy: 0.8231 - temporal_stability_loss: 0.6488 - vertical_dominance_loss: 0.0827 - vertical_dominance_mse: 0.0829 - val_coordination_accuracy: 0.6579 - val_coordination_loss: 0.6862 - val_loss: 2.3020 - val_motion_intensity_loss: 0.0190 - val_motion_intensity_mse: 0.0189 - val_periodicity_accuracy: 0.7105 - val_periodicity_loss: 0.5686 - val_temporal_stability_accuracy: 0.7368 - val_temporal_stability_loss: 0.5541 - val_vertical_dominance_loss: 0.0190 - val_vertical_dominance_mse: 0.0250 - learning_rate: 0.0010
# Epoch 9/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - coordination_accuracy: 0.7622 - coordination_loss: 0.6564 - loss: 2.2167 - motion_intensity_loss: 0.1016 - motion_intensity_mse: 0.1017 - periodicity_accuracy: 0.6664 - periodicity_loss: 0.7554 - temporal_stability_accuracy: 0.8222 - temporal_stability_loss: 0.6290 - vertical_dominance_loss: 0.0742 - vertical_dominance_mse: 0.0741 - val_coordination_accuracy: 0.6579 - val_coordination_loss: 0.6740 - val_loss: 2.2654 - val_motion_intensity_loss: 0.0185 - val_motion_intensity_mse: 0.0225 - val_periodicity_accuracy: 0.7105 - val_periodicity_loss: 0.5430 - val_temporal_stability_accuracy: 0.7368 - val_temporal_stability_loss: 0.5376 - val_vertical_dominance_loss: 0.0212 - val_vertical_dominance_mse: 0.0239 - learning_rate: 0.0010
# Epoch 10/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - coordination_accuracy: 0.7735 - coordination_loss: 0.6441 - loss: 2.1547 - motion_intensity_loss: 0.0888 - motion_intensity_mse: 0.0886 - periodicity_accuracy: 0.6688 - periodicity_loss: 0.7400 - temporal_stability_accuracy: 0.8271 - temporal_stability_loss: 0.6140 - vertical_dominance_loss: 0.0683 - vertical_dominance_mse: 0.0681 - val_coordination_accuracy: 0.6579 - val_coordination_loss: 0.6532 - val_loss: 2.2175 - val_motion_intensity_loss: 0.0174 - val_motion_intensity_mse: 0.0205 - val_periodicity_accuracy: 0.7368 - val_periodicity_loss: 0.5441 - val_temporal_stability_accuracy: 0.7368 - val_temporal_stability_loss: 0.5229 - val_vertical_dominance_loss: 0.0167 - val_vertical_dominance_mse: 0.0200 - learning_rate: 0.0010
# Epoch 11/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - coordination_accuracy: 0.7768 - coordination_loss: 0.6257 - loss: 2.0787 - motion_intensity_loss: 0.0828 - motion_intensity_mse: 0.0825 - periodicity_accuracy: 0.6688 - periodicity_loss: 0.7372 - temporal_stability_accuracy: 0.8393 - temporal_stability_loss: 0.5791 - vertical_dominance_loss: 0.0560 - vertical_dominance_mse: 0.0562 - val_coordination_accuracy: 0.6842 - val_coordination_loss: 0.6263 - val_loss: 2.1733 - val_motion_intensity_loss: 0.0151 - val_motion_intensity_mse: 0.0184 - val_periodicity_accuracy: 0.7368 - val_periodicity_loss: 0.5487 - val_temporal_stability_accuracy: 0.7632 - val_temporal_stability_loss: 0.5176 - val_vertical_dominance_loss: 0.0129 - val_vertical_dominance_mse: 0.0172 - learning_rate: 0.0010
# Epoch 12/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - coordination_accuracy: 0.7784 - coordination_loss: 0.5917 - loss: 2.0012 - motion_intensity_loss: 0.0752 - motion_intensity_mse: 0.0752 - periodicity_accuracy: 0.6623 - periodicity_loss: 0.7288 - temporal_stability_accuracy: 0.8401 - temporal_stability_loss: 0.5522 - vertical_dominance_loss: 0.0487 - vertical_dominance_mse: 0.0489 - val_coordination_accuracy: 0.7105 - val_coordination_loss: 0.6046 - val_loss: 2.1423 - val_motion_intensity_loss: 0.0158 - val_motion_intensity_mse: 0.0228 - val_periodicity_accuracy: 0.7368 - val_periodicity_loss: 0.5355 - val_temporal_stability_accuracy: 0.7632 - val_temporal_stability_loss: 0.5082 - val_vertical_dominance_loss: 0.0133 - val_vertical_dominance_mse: 0.0178 - learning_rate: 0.0010
# Epoch 13/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - coordination_accuracy: 0.8003 - coordination_loss: 0.5918 - loss: 1.9548 - motion_intensity_loss: 0.0689 - motion_intensity_mse: 0.0690 - periodicity_accuracy: 0.6989 - periodicity_loss: 0.6964 - temporal_stability_accuracy: 0.8450 - temporal_stability_loss: 0.5506 - vertical_dominance_loss: 0.0491 - vertical_dominance_mse: 0.0493 - val_coordination_accuracy: 0.7105 - val_coordination_loss: 0.5944 - val_loss: 2.1288 - val_motion_intensity_loss: 0.0132 - val_motion_intensity_mse: 0.0188 - val_periodicity_accuracy: 0.7105 - val_periodicity_loss: 0.5211 - val_temporal_stability_accuracy: 0.7632 - val_temporal_stability_loss: 0.4986 - val_vertical_dominance_loss: 0.0124 - val_vertical_dominance_mse: 0.0161 - learning_rate: 0.0010
# Epoch 14/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - coordination_accuracy: 0.7963 - coordination_loss: 0.5835 - loss: 1.9251 - motion_intensity_loss: 0.0664 - motion_intensity_mse: 0.0666 - periodicity_accuracy: 0.6826 - periodicity_loss: 0.7019 - temporal_stability_accuracy: 0.8425 - temporal_stability_loss: 0.5305 - vertical_dominance_loss: 0.0396 - vertical_dominance_mse: 0.0397 - val_coordination_accuracy: 0.6842 - val_coordination_loss: 0.5812 - val_loss: 2.1085 - val_motion_intensity_loss: 0.0125 - val_motion_intensity_mse: 0.0172 - val_periodicity_accuracy: 0.7105 - val_periodicity_loss: 0.5243 - val_temporal_stability_accuracy: 0.7632 - val_temporal_stability_loss: 0.5009 - val_vertical_dominance_loss: 0.0116 - val_vertical_dominance_mse: 0.0155 - learning_rate: 0.0010
# Epoch 15/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - coordination_accuracy: 0.8036 - coordination_loss: 0.5648 - loss: 1.8537 - motion_intensity_loss: 0.0522 - motion_intensity_mse: 0.0523 - periodicity_accuracy: 0.7102 - periodicity_loss: 0.6775 - temporal_stability_accuracy: 0.8450 - temporal_stability_loss: 0.5221 - vertical_dominance_loss: 0.0385 - vertical_dominance_mse: 0.0385 - val_coordination_accuracy: 0.6842 - val_coordination_loss: 0.5931 - val_loss: 2.1054 - val_motion_intensity_loss: 0.0139 - val_motion_intensity_mse: 0.0174 - val_periodicity_accuracy: 0.7105 - val_periodicity_loss: 0.5169 - val_temporal_stability_accuracy: 0.7368 - val_temporal_stability_loss: 0.4888 - val_vertical_dominance_loss: 0.0105 - val_vertical_dominance_mse: 0.0146 - learning_rate: 0.0010
# Epoch 16/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - coordination_accuracy: 0.8133 - coordination_loss: 0.5422 - loss: 1.8031 - motion_intensity_loss: 0.0538 - motion_intensity_mse: 0.0540 - periodicity_accuracy: 0.7021 - periodicity_loss: 0.6712 - temporal_stability_accuracy: 0.8466 - temporal_stability_loss: 0.5075 - vertical_dominance_loss: 0.0346 - vertical_dominance_mse: 0.0345 - val_coordination_accuracy: 0.7105 - val_coordination_loss: 0.5611 - val_loss: 2.0986 - val_motion_intensity_loss: 0.0128 - val_motion_intensity_mse: 0.0191 - val_periodicity_accuracy: 0.6842 - val_periodicity_loss: 0.5090 - val_temporal_stability_accuracy: 0.7368 - val_temporal_stability_loss: 0.4899 - val_vertical_dominance_loss: 0.0115 - val_vertical_dominance_mse: 0.0145 - learning_rate: 0.0010
# Epoch 17/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - coordination_accuracy: 0.8279 - coordination_loss: 0.5386 - loss: 1.7805 - motion_intensity_loss: 0.0502 - motion_intensity_mse: 0.0503 - periodicity_accuracy: 0.7005 - periodicity_loss: 0.6808 - temporal_stability_accuracy: 0.8555 - temporal_stability_loss: 0.4829 - vertical_dominance_loss: 0.0283 - vertical_dominance_mse: 0.0283 - val_coordination_accuracy: 0.6842 - val_coordination_loss: 0.5510 - val_loss: 2.0938 - val_motion_intensity_loss: 0.0117 - val_motion_intensity_mse: 0.0170 - val_periodicity_accuracy: 0.7105 - val_periodicity_loss: 0.5275 - val_temporal_stability_accuracy: 0.7368 - val_temporal_stability_loss: 0.4872 - val_vertical_dominance_loss: 0.0116 - val_vertical_dominance_mse: 0.0150 - learning_rate: 0.0010
# Epoch 18/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - coordination_accuracy: 0.8231 - coordination_loss: 0.5201 - loss: 1.7276 - motion_intensity_loss: 0.0452 - motion_intensity_mse: 0.0451 - periodicity_accuracy: 0.7062 - periodicity_loss: 0.6546 - temporal_stability_accuracy: 0.8531 - temporal_stability_loss: 0.4728 - vertical_dominance_loss: 0.0293 - vertical_dominance_mse: 0.0290 - val_coordination_accuracy: 0.6842 - val_coordination_loss: 0.5340 - val_loss: 2.0775 - val_motion_intensity_loss: 0.0117 - val_motion_intensity_mse: 0.0177 - val_periodicity_accuracy: 0.6842 - val_periodicity_loss: 0.5149 - val_temporal_stability_accuracy: 0.7632 - val_temporal_stability_loss: 0.4910 - val_vertical_dominance_loss: 0.0114 - val_vertical_dominance_mse: 0.0145 - learning_rate: 0.0010
# Epoch 19/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - coordination_accuracy: 0.8344 - coordination_loss: 0.4927 - loss: 1.6702 - motion_intensity_loss: 0.0400 - motion_intensity_mse: 0.0400 - periodicity_accuracy: 0.7143 - periodicity_loss: 0.6399 - temporal_stability_accuracy: 0.8563 - temporal_stability_loss: 0.4684 - vertical_dominance_loss: 0.0247 - vertical_dominance_mse: 0.0247 - val_coordination_accuracy: 0.7105 - val_coordination_loss: 0.5216 - val_loss: 2.0792 - val_motion_intensity_loss: 0.0108 - val_motion_intensity_mse: 0.0157 - val_periodicity_accuracy: 0.6579 - val_periodicity_loss: 0.5227 - val_temporal_stability_accuracy: 0.7632 - val_temporal_stability_loss: 0.4931 - val_vertical_dominance_loss: 0.0112 - val_vertical_dominance_mse: 0.0141 - learning_rate: 0.0010
# Epoch 20/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - coordination_accuracy: 0.8271 - coordination_loss: 0.5020 - loss: 1.6486 - motion_intensity_loss: 0.0384 - motion_intensity_mse: 0.0385 - periodicity_accuracy: 0.7183 - periodicity_loss: 0.6411 - temporal_stability_accuracy: 0.8596 - temporal_stability_loss: 0.4460 - vertical_dominance_loss: 0.0210 - vertical_dominance_mse: 0.0210 - val_coordination_accuracy: 0.7105 - val_coordination_loss: 0.5157 - val_loss: 2.0829 - val_motion_intensity_loss: 0.0110 - val_motion_intensity_mse: 0.0149 - val_periodicity_accuracy: 0.7105 - val_periodicity_loss: 0.5269 - val_temporal_stability_accuracy: 0.7632 - val_temporal_stability_loss: 0.4850 - val_vertical_dominance_loss: 0.0086 - val_vertical_dominance_mse: 0.0116 - learning_rate: 0.0010
# Epoch 21/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - coordination_accuracy: 0.8385 - coordination_loss: 0.4816 - loss: 1.6033 - motion_intensity_loss: 0.0387 - motion_intensity_mse: 0.0389 - periodicity_accuracy: 0.7273 - periodicity_loss: 0.6232 - temporal_stability_accuracy: 0.8506 - temporal_stability_loss: 0.4421 - vertical_dominance_loss: 0.0218 - vertical_dominance_mse: 0.0220 - val_coordination_accuracy: 0.6842 - val_coordination_loss: 0.5182 - val_loss: 2.0447 - val_motion_intensity_loss: 0.0101 - val_motion_intensity_mse: 0.0138 - val_periodicity_accuracy: 0.6842 - val_periodicity_loss: 0.5177 - val_temporal_stability_accuracy: 0.7368 - val_temporal_stability_loss: 0.4710 - val_vertical_dominance_loss: 0.0091 - val_vertical_dominance_mse: 0.0117 - learning_rate: 0.0010
# Epoch 22/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - coordination_accuracy: 0.8369 - coordination_loss: 0.4788 - loss: 1.5510 - motion_intensity_loss: 0.0317 - motion_intensity_mse: 0.0318 - periodicity_accuracy: 0.7435 - periodicity_loss: 0.5966 - temporal_stability_accuracy: 0.8644 - temporal_stability_loss: 0.4196 - vertical_dominance_loss: 0.0196 - vertical_dominance_mse: 0.0197 - val_coordination_accuracy: 0.7105 - val_coordination_loss: 0.5127 - val_loss: 2.0818 - val_motion_intensity_loss: 0.0113 - val_motion_intensity_mse: 0.0147 - val_periodicity_accuracy: 0.7105 - val_periodicity_loss: 0.5281 - val_temporal_stability_accuracy: 0.7368 - val_temporal_stability_loss: 0.4700 - val_vertical_dominance_loss: 0.0072 - val_vertical_dominance_mse: 0.0103 - learning_rate: 0.0010
# Epoch 23/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - coordination_accuracy: 0.8328 - coordination_loss: 0.4814 - loss: 1.5548 - motion_intensity_loss: 0.0303 - motion_intensity_mse: 0.0305 - periodicity_accuracy: 0.7532 - periodicity_loss: 0.5986 - temporal_stability_accuracy: 0.8612 - temporal_stability_loss: 0.4284 - vertical_dominance_loss: 0.0189 - vertical_dominance_mse: 0.0189 - val_coordination_accuracy: 0.6842 - val_coordination_loss: 0.5015 - val_loss: 2.0792 - val_motion_intensity_loss: 0.0099 - val_motion_intensity_mse: 0.0145 - val_periodicity_accuracy: 0.6579 - val_periodicity_loss: 0.5413 - val_temporal_stability_accuracy: 0.7368 - val_temporal_stability_loss: 0.4622 - val_vertical_dominance_loss: 0.0091 - val_vertical_dominance_mse: 0.0120 - learning_rate: 0.0010
# Epoch 24/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - coordination_accuracy: 0.8401 - coordination_loss: 0.4798 - loss: 1.5412 - motion_intensity_loss: 0.0304 - motion_intensity_mse: 0.0304 - periodicity_accuracy: 0.7338 - periodicity_loss: 0.6013 - temporal_stability_accuracy: 0.8677 - temporal_stability_loss: 0.4165 - vertical_dominance_loss: 0.0178 - vertical_dominance_mse: 0.0177 - val_coordination_accuracy: 0.7105 - val_coordination_loss: 0.4826 - val_loss: 2.0634 - val_motion_intensity_loss: 0.0086 - val_motion_intensity_mse: 0.0123 - val_periodicity_accuracy: 0.7105 - val_periodicity_loss: 0.5528 - val_temporal_stability_accuracy: 0.7368 - val_temporal_stability_loss: 0.4717 - val_vertical_dominance_loss: 0.0089 - val_vertical_dominance_mse: 0.0120 - learning_rate: 0.0010
# Epoch 25/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - coordination_accuracy: 0.8385 - coordination_loss: 0.4638 - loss: 1.5084 - motion_intensity_loss: 0.0264 - motion_intensity_mse: 0.0261 - periodicity_accuracy: 0.7468 - periodicity_loss: 0.5875 - temporal_stability_accuracy: 0.8726 - temporal_stability_loss: 0.4118 - vertical_dominance_loss: 0.0158 - vertical_dominance_mse: 0.0155 - val_coordination_accuracy: 0.7105 - val_coordination_loss: 0.5201 - val_loss: 2.0769 - val_motion_intensity_loss: 0.0081 - val_motion_intensity_mse: 0.0122 - val_periodicity_accuracy: 0.6842 - val_periodicity_loss: 0.5426 - val_temporal_stability_accuracy: 0.7105 - val_temporal_stability_loss: 0.4680 - val_vertical_dominance_loss: 0.0065 - val_vertical_dominance_mse: 0.0093 - learning_rate: 0.0010
# Epoch 26/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - coordination_accuracy: 0.8320 - coordination_loss: 0.4642 - loss: 1.4781 - motion_intensity_loss: 0.0232 - motion_intensity_mse: 0.0230 - periodicity_accuracy: 0.7378 - periodicity_loss: 0.5896 - temporal_stability_accuracy: 0.8701 - temporal_stability_loss: 0.3945 - vertical_dominance_loss: 0.0141 - vertical_dominance_mse: 0.0140 - val_coordination_accuracy: 0.7368 - val_coordination_loss: 0.4807 - val_loss: 2.0354 - val_motion_intensity_loss: 0.0084 - val_motion_intensity_mse: 0.0122 - val_periodicity_accuracy: 0.7105 - val_periodicity_loss: 0.5339 - val_temporal_stability_accuracy: 0.7632 - val_temporal_stability_loss: 0.4648 - val_vertical_dominance_loss: 0.0067 - val_vertical_dominance_mse: 0.0094 - learning_rate: 0.0010
# Epoch 27/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - coordination_accuracy: 0.8393 - coordination_loss: 0.4431 - loss: 1.4699 - motion_intensity_loss: 0.0203 - motion_intensity_mse: 0.0203 - periodicity_accuracy: 0.7443 - periodicity_loss: 0.5874 - temporal_stability_accuracy: 0.8596 - temporal_stability_loss: 0.4025 - vertical_dominance_loss: 0.0129 - vertical_dominance_mse: 0.0129 - val_coordination_accuracy: 0.7105 - val_coordination_loss: 0.4955 - val_loss: 1.9989 - val_motion_intensity_loss: 0.0085 - val_motion_intensity_mse: 0.0123 - val_periodicity_accuracy: 0.7368 - val_periodicity_loss: 0.5444 - val_temporal_stability_accuracy: 0.7368 - val_temporal_stability_loss: 0.4493 - val_vertical_dominance_loss: 0.0065 - val_vertical_dominance_mse: 0.0091 - learning_rate: 0.0010
# Epoch 28/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - coordination_accuracy: 0.8433 - coordination_loss: 0.4392 - loss: 1.4148 - motion_intensity_loss: 0.0192 - motion_intensity_mse: 0.0193 - periodicity_accuracy: 0.7638 - periodicity_loss: 0.5490 - temporal_stability_accuracy: 0.8693 - temporal_stability_loss: 0.3906 - vertical_dominance_loss: 0.0118 - vertical_dominance_mse: 0.0117 - val_coordination_accuracy: 0.6842 - val_coordination_loss: 0.4859 - val_loss: 2.0183 - val_motion_intensity_loss: 0.0078 - val_motion_intensity_mse: 0.0107 - val_periodicity_accuracy: 0.7105 - val_periodicity_loss: 0.5212 - val_temporal_stability_accuracy: 0.7632 - val_temporal_stability_loss: 0.4582 - val_vertical_dominance_loss: 0.0066 - val_vertical_dominance_mse: 0.0091 - learning_rate: 0.0010
# Epoch 29/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - coordination_accuracy: 0.8409 - coordination_loss: 0.4328 - loss: 1.3772 - motion_intensity_loss: 0.0172 - motion_intensity_mse: 0.0172 - periodicity_accuracy: 0.7971 - periodicity_loss: 0.5403 - temporal_stability_accuracy: 0.8774 - temporal_stability_loss: 0.3746 - vertical_dominance_loss: 0.0115 - vertical_dominance_mse: 0.0115 - val_coordination_accuracy: 0.7105 - val_coordination_loss: 0.5196 - val_loss: 2.0751 - val_motion_intensity_loss: 0.0068 - val_motion_intensity_mse: 0.0101 - val_periodicity_accuracy: 0.6842 - val_periodicity_loss: 0.5055 - val_temporal_stability_accuracy: 0.7368 - val_temporal_stability_loss: 0.4650 - val_vertical_dominance_loss: 0.0069 - val_vertical_dominance_mse: 0.0094 - learning_rate: 0.0010
# Epoch 30/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - coordination_accuracy: 0.8425 - coordination_loss: 0.4346 - loss: 1.4172 - motion_intensity_loss: 0.0173 - motion_intensity_mse: 0.0172 - periodicity_accuracy: 0.7557 - periodicity_loss: 0.5634 - temporal_stability_accuracy: 0.8661 - temporal_stability_loss: 0.3955 - vertical_dominance_loss: 0.0108 - vertical_dominance_mse: 0.0108 - val_coordination_accuracy: 0.7105 - val_coordination_loss: 0.5071 - val_loss: 2.0794 - val_motion_intensity_loss: 0.0055 - val_motion_intensity_mse: 0.0084 - val_periodicity_accuracy: 0.6842 - val_periodicity_loss: 0.5339 - val_temporal_stability_accuracy: 0.7368 - val_temporal_stability_loss: 0.4599 - val_vertical_dominance_loss: 0.0069 - val_vertical_dominance_mse: 0.0094 - learning_rate: 0.0010
# Epoch 31/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - coordination_accuracy: 0.8490 - coordination_loss: 0.4160 - loss: 1.3702 - motion_intensity_loss: 0.0141 - motion_intensity_mse: 0.0140 - periodicity_accuracy: 0.7841 - periodicity_loss: 0.5396 - temporal_stability_accuracy: 0.8653 - temporal_stability_loss: 0.3865 - vertical_dominance_loss: 0.0107 - vertical_dominance_mse: 0.0107 - val_coordination_accuracy: 0.7105 - val_coordination_loss: 0.4844 - val_loss: 2.0869 - val_motion_intensity_loss: 0.0045 - val_motion_intensity_mse: 0.0067 - val_periodicity_accuracy: 0.6842 - val_periodicity_loss: 0.5605 - val_temporal_stability_accuracy: 0.7105 - val_temporal_stability_loss: 0.4615 - val_vertical_dominance_loss: 0.0064 - val_vertical_dominance_mse: 0.0086 - learning_rate: 0.0010
# Epoch 32/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - coordination_accuracy: 0.8482 - coordination_loss: 0.4324 - loss: 1.3908 - motion_intensity_loss: 0.0127 - motion_intensity_mse: 0.0127 - periodicity_accuracy: 0.7670 - periodicity_loss: 0.5481 - temporal_stability_accuracy: 0.8620 - temporal_stability_loss: 0.3854 - vertical_dominance_loss: 0.0101 - vertical_dominance_mse: 0.0101 - val_coordination_accuracy: 0.7105 - val_coordination_loss: 0.4749 - val_loss: 2.0030 - val_motion_intensity_loss: 0.0048 - val_motion_intensity_mse: 0.0062 - val_periodicity_accuracy: 0.7105 - val_periodicity_loss: 0.5504 - val_temporal_stability_accuracy: 0.7632 - val_temporal_stability_loss: 0.4475 - val_vertical_dominance_loss: 0.0067 - val_vertical_dominance_mse: 0.0087 - learning_rate: 0.0010
# Epoch 33/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - coordination_accuracy: 0.8474 - coordination_loss: 0.4250 - loss: 1.3196 - motion_intensity_loss: 0.0116 - motion_intensity_mse: 0.0117 - periodicity_accuracy: 0.7914 - periodicity_loss: 0.5122 - temporal_stability_accuracy: 0.8750 - temporal_stability_loss: 0.3607 - vertical_dominance_loss: 0.0092 - vertical_dominance_mse: 0.0092 - val_coordination_accuracy: 0.7105 - val_coordination_loss: 0.4944 - val_loss: 2.0691 - val_motion_intensity_loss: 0.0043 - val_motion_intensity_mse: 0.0062 - val_periodicity_accuracy: 0.6842 - val_periodicity_loss: 0.5352 - val_temporal_stability_accuracy: 0.7368 - val_temporal_stability_loss: 0.4630 - val_vertical_dominance_loss: 0.0058 - val_vertical_dominance_mse: 0.0079 - learning_rate: 5.0000e-04
# Epoch 34/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - coordination_accuracy: 0.8669 - coordination_loss: 0.3960 - loss: 1.2909 - motion_intensity_loss: 0.0100 - motion_intensity_mse: 0.0100 - periodicity_accuracy: 0.7873 - periodicity_loss: 0.5222 - temporal_stability_accuracy: 0.8807 - temporal_stability_loss: 0.3561 - vertical_dominance_loss: 0.0087 - vertical_dominance_mse: 0.0087 - val_coordination_accuracy: 0.7105 - val_coordination_loss: 0.4841 - val_loss: 2.0275 - val_motion_intensity_loss: 0.0042 - val_motion_intensity_mse: 0.0062 - val_periodicity_accuracy: 0.7105 - val_periodicity_loss: 0.5332 - val_temporal_stability_accuracy: 0.7368 - val_temporal_stability_loss: 0.4624 - val_vertical_dominance_loss: 0.0055 - val_vertical_dominance_mse: 0.0074 - learning_rate: 5.0000e-04
# Epoch 35/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - coordination_accuracy: 0.8636 - coordination_loss: 0.4016 - loss: 1.3058 - motion_intensity_loss: 0.0100 - motion_intensity_mse: 0.0101 - periodicity_accuracy: 0.7622 - periodicity_loss: 0.5393 - temporal_stability_accuracy: 0.8823 - temporal_stability_loss: 0.3519 - vertical_dominance_loss: 0.0087 - vertical_dominance_mse: 0.0088 - val_coordination_accuracy: 0.7368 - val_coordination_loss: 0.4811 - val_loss: 2.0127 - val_motion_intensity_loss: 0.0038 - val_motion_intensity_mse: 0.0055 - val_periodicity_accuracy: 0.7105 - val_periodicity_loss: 0.5488 - val_temporal_stability_accuracy: 0.7105 - val_temporal_stability_loss: 0.4497 - val_vertical_dominance_loss: 0.0053 - val_vertical_dominance_mse: 0.0072 - learning_rate: 5.0000e-04
# Epoch 36/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - coordination_accuracy: 0.8571 - coordination_loss: 0.4079 - loss: 1.2878 - motion_intensity_loss: 0.0096 - motion_intensity_mse: 0.0096 - periodicity_accuracy: 0.7833 - periodicity_loss: 0.5173 - temporal_stability_accuracy: 0.8782 - temporal_stability_loss: 0.3495 - vertical_dominance_loss: 0.0083 - vertical_dominance_mse: 0.0083 - val_coordination_accuracy: 0.7105 - val_coordination_loss: 0.5039 - val_loss: 2.0336 - val_motion_intensity_loss: 0.0041 - val_motion_intensity_mse: 0.0059 - val_periodicity_accuracy: 0.7105 - val_periodicity_loss: 0.5299 - val_temporal_stability_accuracy: 0.7368 - val_temporal_stability_loss: 0.4568 - val_vertical_dominance_loss: 0.0057 - val_vertical_dominance_mse: 0.0075 - learning_rate: 5.0000e-04
# Epoch 37/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - coordination_accuracy: 0.8693 - coordination_loss: 0.3961 - loss: 1.2682 - motion_intensity_loss: 0.0094 - motion_intensity_mse: 0.0093 - periodicity_accuracy: 0.7735 - periodicity_loss: 0.5308 - temporal_stability_accuracy: 0.8912 - temporal_stability_loss: 0.3214 - vertical_dominance_loss: 0.0085 - vertical_dominance_mse: 0.0086 - val_coordination_accuracy: 0.7105 - val_coordination_loss: 0.5055 - val_loss: 2.0387 - val_motion_intensity_loss: 0.0037 - val_motion_intensity_mse: 0.0055 - val_periodicity_accuracy: 0.7105 - val_periodicity_loss: 0.5501 - val_temporal_stability_accuracy: 0.7368 - val_temporal_stability_loss: 0.4596 - val_vertical_dominance_loss: 0.0058 - val_vertical_dominance_mse: 0.0075 - learning_rate: 5.0000e-04
# Training completed!

# %%
def calculate_auroc_multi_output(y_true_categorical, y_pred_proba, concept_name, num_classes):
    """
    Calculate AUROC for multi-output CNN concepts
    
    Args:
        y_true_categorical: True labels in categorical format
        y_pred_proba: Predicted probabilities from model
        concept_name: Name of the concept (for discrete concepts only)
        num_classes: Number of classes for this concept
    
    Returns:
        AUROC score
    """
    # Convert categorical to integer labels
    y_true = np.argmax(y_true_categorical, axis=1)
    
    # For binary classification (2 classes)
    if num_classes == 2:
        # Use the probability of the positive class
        y_scores = y_pred_proba[:, 1]
        return roc_auc_score(y_true, y_scores)
    else:
        # Binarize the labels for multi-class AUROC calculation
        y_true_bin = label_binarize(y_true, classes=range(num_classes))
        
        if y_true_bin.shape[1] == 1:
            # Binary case
            return roc_auc_score(y_true_bin, y_pred_proba[:, 1])
        else:
            # Multi-class case
            return roc_auc_score(y_true_bin, y_pred_proba, multi_class='ovr', average='macro')

# %%
y_test_map = {
    'periodicity': y_p_test_cat,
    'temporal_stability': y_t_test_cat,
    'coordination': y_c_test_cat,
    'motion_intensity': y_mi_test_cat,
    'vertical_dominance': y_vd_test_cat,
}

# Evaluate model
print("Evaluating model...")
results = model.evaluate(X_test, list(y_test_map.values()), verbose=0)


predictions = model.predict(X_test, verbose=0)
periodicity_pred = np.argmax(predictions[0], axis=1)
temporal_stability_pred = np.argmax(predictions[1], axis=1)
coordination_pred = np.argmax(predictions[2], axis=1)
motion_intensity_pred = np.argmax(predictions[3], axis=1)
vertical_dominance_pred = np.argmax(predictions[4], axis=1)

periodicity_acc = accuracy_score(np.argmax(y_p_test_cat, axis=1), periodicity_pred)
temporal_stability_acc = accuracy_score(np.argmax(y_t_test_cat, axis=1), temporal_stability_pred)
coordination_acc = accuracy_score(np.argmax(y_c_test_cat, axis=1), coordination_pred)
motion_intensity_acc = accuracy_score(np.argmax(y_mi_test_cat, axis=1), motion_intensity_pred)
vertical_dominance_acc = accuracy_score(np.argmax(y_vd_test_cat, axis=1), vertical_dominance_pred)

periodicity_auroc = calculate_auroc_multi_output(y_p_test_cat, predictions[0], 'periodicity', 3)
temporal_stability_auroc = calculate_auroc_multi_output(y_t_test_cat, predictions[1], 'temporal_stability', 3)
coordination_auroc = calculate_auroc_multi_output(y_c_test_cat, predictions[2], 'coordination', 3)

from sklearn.metrics import r2_score
motion_intensity_r2 = r2_score(y_mi_test_cat.flatten(), predictions[3].flatten())
vertical_dominance_r2 = r2_score(y_vd_test_cat.flatten(), predictions[4].flatten())

overall_acc = (periodicity_acc + temporal_stability_acc + coordination_acc + motion_intensity_acc + vertical_dominance_acc) / len(concept_columns)

auroc_scores = [periodicity_auroc, temporal_stability_auroc, coordination_auroc]
valid_auroc_scores = [score for score in auroc_scores if not np.isnan(score)]
overall_auroc = np.mean(valid_auroc_scores) if valid_auroc_scores else 0.5

print(f"\n=== RESULTS ===")
print(f"\n--- Classification Concepts (Discrete) ---")
print(f"Periodicity - Accuracy: {periodicity_acc:.4f}, AUROC: {periodicity_auroc:.4f}")
print(f"Temporal Stability - Accuracy: {temporal_stability_acc:.4f}, AUROC: {temporal_stability_auroc:.4f}")
print(f"Coordination - Accuracy: {coordination_acc:.4f}, AUROC: {coordination_auroc:.4f}")

print(f"\n--- Regression Concepts (Continuous) ---")
print(f"Motion Intensity - Accuracy: {motion_intensity_acc:.4f}, R²: {motion_intensity_r2:.4f}")
print(f"Vertical Dominance - Accuracy: {vertical_dominance_acc:.4f}, R²: {vertical_dominance_r2:.4f}")

print(f"\n--- Overall Performance ---")
print(f"Overall Average Accuracy: {overall_acc*100:.1f}%")
print(f"Overall Average AUROC (classification concepts): {overall_auroc:.4f}")
# Out:
# Evaluating model...
#
# === RESULTS ===
#
# --- Classification Concepts (Discrete) ---
# Periodicity - Accuracy: 0.7368, AUROC: 0.8666
# Temporal Stability - Accuracy: 0.7368, AUROC: 0.8546
# Coordination - Accuracy: 0.7105, AUROC: 0.8393
#
# --- Regression Concepts (Continuous) ---
# Motion Intensity - Accuracy: 1.0000, R²: -4.9433
# Vertical Dominance - Accuracy: 1.0000, R²: -0.1511
#
# --- Overall Performance ---
# Overall Average Accuracy: 83.7%
# Overall Average AUROC (classification concepts): 0.8535

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 8))

for i, concept in enumerate(discrete_concepts):
    row, col = i // 2, i % 2
    axes[row, col].plot(history.history[f'{concept}_accuracy'], label=f'{concept.title()} Accuracy')
    axes[row, col].plot(history.history[f'val_{concept}_accuracy'], label=f'Val {concept.title()} Accuracy')
    axes[row, col].set_title(f'{concept.title()} Accuracy')
    axes[row, col].set_xlabel('Epoch')
    axes[row, col].set_ylabel('Accuracy')
    axes[row, col].legend()
    axes[row, col].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()


fig, axes = plt.subplots(1, 2, figsize=(12, 4))

for i, concept in enumerate(continuous_concepts):
    axes[i].plot(history.history[f'{concept}_mse'], label=f'{concept.title()} MSE')
    axes[i].plot(history.history[f'val_{concept}_mse'], label=f'Val {concept.title()} MSE')
    axes[i].set_title(f'{concept.title()} MSE')
    axes[i].set_xlabel('Epoch')
    axes[i].set_ylabel('MSE')
    axes[i].legend()
    axes[i].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %%
model.save("./models/sensor_data_to_concept_model.keras")
print("Model saved to /models/sensor_data_to_concept_model.keras")
# Out:
# Model saved to /models/sensor_data_to_concept_model.keras
