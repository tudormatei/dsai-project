# %% [markdown]
# # Quick CNN Training - Ultra Lightweight + Augmentation
# ## Streamlined version for rapid iteration
#
# This notebook contains only the essential components for training the ultra-lightweight CNN with augmentation and stratified random shuffle split.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, roc_auc_score
from sklearn.preprocessing import label_binarize
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
from tensorflow.keras.utils import to_categorical
import warnings
warnings.filterwarnings('ignore')

print(f"TensorFlow version: {tf.__version__}")
print(f"Keras version: {keras.__version__}")
# Out:
# TensorFlow version: 2.20.0
# Keras version: 3.11.3

# %%
# CONFIG
df_sensor = pd.read_csv('./data/final_dataset.csv')
df_windows = pd.read_csv('./data/final_window_labels.csv') 

concept_columns = {'periodicity', 'temporal_stability', 'coordination', 'motion_intensity', 'vertical_dominance'}
discrete_concepts = {'periodicity', 'temporal_stability', 'coordination'}
continuous_concepts = {'motion_intensity', 'vertical_dominance'}

# %%
print(f"Sensor data: {len(df_sensor)} readings")
print(f"Manual labels: {len(df_windows)} windows")
print(f"\nLabeled windows:")
print(df_windows.head())

print(f"\nAvailable concepts: {concept_columns}")
print(f"\nConcept distributions:")

for concept in concept_columns:
    if concept not in df_windows.columns:
        print(f"  {concept}: (missing from data)")
        continue

    if concept in discrete_concepts:
        print(f"\n  [Discrete] {concept}:")
        print(df_windows[concept].value_counts(dropna=False))
    elif concept in continuous_concepts:
        print(f"\n  [Continuous] {concept}:")
        print(df_windows[concept].describe())
    else:
        print(f"\n  [Unknown type] {concept}:")
        print(df_windows[concept].head())
# Out:
# Sensor data: 8802 readings
# Manual labels: 150 windows
#
# Labeled windows:
#    window_idx  user activity  start_time  end_time  periodicity  \
# 0           0     3  Walking      957.75    960.75          1.0
# 1           1     3  Walking       42.00     45.00          1.0
# 2           2     3  Walking      871.50    874.50          0.5
# 3           3     3  Walking       63.00     66.00          1.0
# 4           4     3  Jogging      117.75    120.75          1.0
#
#    temporal_stability  coordination  motion_intensity  vertical_dominance
# 0                 0.5           0.5          0.316815            0.221105
# 1                 0.5           0.5          0.302850            0.291116
# 2                 0.5           0.5          0.303036            0.181147
# 3                 0.5           0.5          0.313779            0.305797
# 4                 0.5           0.5          0.408648            0.262989
#
# Available concepts: {'coordination', 'vertical_dominance', 'motion_intensity', 'temporal_stability', 'periodicity'}
#
# Concept distributions:
#
#   [Discrete] coordination:
# coordination
# 1.0    70
# 0.5    64
# 0.0    16
# Name: count, dtype: int64
#
#   [Continuous] vertical_dominance:
# count    150.000000
# mean       0.248287
# std        0.080944
# min        0.041401
# 25%        0.201228
# 50%        0.236932
# 75%        0.291116
# max        0.562017
# Name: vertical_dominance, dtype: float64
#
#   [Continuous] motion_intensity:
# count    150.000000
# mean       0.331157
# std        0.041124
# min        0.277237
# 25%        0.304296
# 50%        0.316702
# 75%        0.338431
# max        0.471138
# Name: motion_intensity, dtype: float64
#
#   [Discrete] temporal_stability:
# temporal_stability
# 0.5    87
# 1.0    51
# 0.0    12
# Name: count, dtype: int64
#
#   [Discrete] periodicity:
# periodicity
# 0.0    90
# 0.5    35
# 1.0    25
# Name: count, dtype: int64

# %%
def extract_window_robust(df_sensor, window_row, time_tolerance=0.5):
    """
    Extract sensor data with time tolerance to handle mismatches.
    """
    user = window_row['user']
    activity = window_row['activity']
    start_time = window_row['start_time']
    end_time = window_row['end_time']
    
    # Get data for this user/activity
    user_activity_data = df_sensor[(df_sensor['user'] == user) & 
                                  (df_sensor['activity'] == activity)].copy()
    
    if len(user_activity_data) == 0:
        return None
    
    # Find data within time window with tolerance
    mask = ((user_activity_data['time_s'] >= start_time - time_tolerance) & 
            (user_activity_data['time_s'] <= end_time + time_tolerance))
    
    window_data = user_activity_data[mask]
    
    if len(window_data) < 10:  # Need minimum samples
        return None
    
    # Extract sensor readings
    sensor_data = window_data[['x-axis', 'y-axis', 'z-axis']].values
    
    # Pad or truncate to fixed length (e.g., 100 samples)
    target_length = 60
    if len(sensor_data) > target_length:
        # Randomly sample if too long
        indices = np.random.choice(len(sensor_data), target_length, replace=False)
        sensor_data = sensor_data[indices]
    elif len(sensor_data) < target_length:
        # Pad with last value if too short
        padding = np.tile(sensor_data[-1:], (target_length - len(sensor_data), 1))
        sensor_data = np.vstack([sensor_data, padding])
    
    return sensor_data

def extract_windows_robust(df_sensor, df_windows):
    """
    Extract all windows with robust time matching for 6 concepts.
    """
    X = []
    y_p = []  # periodicity
    y_t = []  # temporal_stability
    y_c = []  # coordination
    y_mi = [] # motion_intensity
    y_vd = [] # vertical_dominance
    
    for _, window_row in df_windows.iterrows():
        window_data = extract_window_robust(df_sensor, window_row)
        if window_data is not None:
            X.append(window_data)
            y_p.append(window_row['periodicity'])
            y_t.append(window_row['temporal_stability'])
            y_c.append(window_row['coordination'])
            y_mi.append(window_row['motion_intensity'])
            y_vd.append(window_row['vertical_dominance'])
    
    return np.array(X), np.array(y_p), np.array(y_t), np.array(y_c), np.array(y_mi), np.array(y_vd)

# %%
def augment_jitter(data, sigma=0.05):
    """Add random Gaussian noise to simulate sensor imperfections"""
    return data + np.random.normal(0, sigma, data.shape)

def augment_scaling(data, sigma=0.1):
    """Scale magnitude to simulate different movement intensities"""
    # Handle different data shapes
    if len(data.shape) == 3:
        factor = np.random.normal(1.0, sigma, (data.shape[0], 1, data.shape[2]))
    elif len(data.shape) == 2:
        factor = np.random.normal(1.0, sigma, (data.shape[0], data.shape[1]))
    else:
        factor = np.random.normal(1.0, sigma, data.shape)
    return data * factor

def augment_rotation(data):
    """Rotate 3D data to simulate different phone orientations"""
    angle = np.random.uniform(-np.pi/6, np.pi/6)  # ±30 degrees
    cos_a, sin_a = np.cos(angle), np.sin(angle)
    rotation_matrix = np.array([
        [cos_a, -sin_a, 0],
        [sin_a, cos_a, 0],
        [0, 0, 1]
    ])
    return np.dot(data, rotation_matrix.T)

def augment_dataset(X, y_p, y_t, y_c, y_mi, y_vd, factor=10):
    """
    Create augmented versions of the dataset for 7 concepts.
    
    Args:
        X: Original data (n_samples, timesteps, 3)
        y_p, y_t, y_c, y_mi, y_vd, y_sp, y_mag: Labels for seven concepts
        factor: Augmentation multiplier (10 = 10x more data)
    
    Returns:
        Augmented dataset with (factor+1) × original size
    """
    n_original = len(X)
    n_augmented = n_original * factor
    
    # Initialize augmented arrays
    X_aug = np.zeros((n_augmented, X.shape[1], X.shape[2]))
    y_p_aug = np.zeros(n_augmented)
    y_t_aug = np.zeros(n_augmented)
    y_c_aug = np.zeros(n_augmented)
    y_mi_aug = np.zeros(n_augmented)
    y_vd_aug = np.zeros(n_augmented)
    
    for i in range(n_augmented):
        # Randomly select original sample
        idx = np.random.randint(0, n_original)
        
        # Apply random augmentation
        aug_type = np.random.choice(['jitter', 'scaling', 'rotation', 'none'])
        
        if aug_type == 'jitter':
            X_aug[i] = augment_jitter(X[idx])
        elif aug_type == 'scaling':
            X_aug[i] = augment_scaling(X[idx])
        elif aug_type == 'rotation':
            X_aug[i] = augment_rotation(X[idx])
        else:  # none
            X_aug[i] = X[idx]
        
        # Copy labels
        y_p_aug[i] = y_p[idx]
        y_t_aug[i] = y_t[idx]
        y_c_aug[i] = y_c[idx]
        y_mi_aug[i] = y_mi[idx]
        y_vd_aug[i] = y_vd[idx]
    
    # Combine original and augmented data
    X_combined = np.vstack([X, X_aug])
    y_p_combined = np.concatenate([y_p, y_p_aug])
    y_t_combined = np.concatenate([y_t, y_t_aug])
    y_c_combined = np.concatenate([y_c, y_c_aug])
    y_mi_combined = np.concatenate([y_mi, y_mi_aug])
    y_vd_combined = np.concatenate([y_vd, y_vd_aug])
    
    return X_combined, y_p_combined, y_t_combined, y_c_combined, y_mi_combined, y_vd_combined

# %%
def build_optimized_cnn(input_shape, n_classes_p, n_classes_t, n_classes_c):
    input_layer = layers.Input(shape=input_shape)
    
    x = layers.Conv1D(16, 3, activation='relu', padding='same')(input_layer)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling1D(2)(x)
    
    x = layers.Conv1D(16, 3, activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.GlobalAveragePooling1D()(x)
    
    x = layers.Dropout(0.4)(x)
    
    # Discrete concepts
    periodicity = layers.Dense(n_classes_p, activation='softmax', name='periodicity')(x)
    temporal_stability = layers.Dense(n_classes_t, activation='softmax', name='temporal_stability')(x)
    coordination = layers.Dense(n_classes_c, activation='softmax', name='coordination')(x)
    
    # Continuous concepts
    motion_intensity = layers.Dense(1, activation='linear', name='motion_intensity')(x)
    vertical_dominance = layers.Dense(1, activation='linear', name='vertical_dominance')(x)
    
    model = models.Model(inputs=input_layer, outputs=[periodicity, temporal_stability, coordination, motion_intensity, vertical_dominance])
    
    return model

# %%
print("Extracting windows...")
X, y_p, y_t, y_c, y_mi, y_vd = extract_windows_robust(df_sensor, df_windows)

print(f"Extracted {len(X)} windows")
print(f"Window shape: {X.shape}")
print(f"Label distributions:")
print(f"  Periodicity: {np.bincount(y_p.astype(int))}")
print(f"  Temporal Stability: {np.bincount(y_t.astype(int))}")
print(f"  Coordination: {np.bincount(y_c.astype(int))}")
print(f"  Motion Intensity: {np.bincount(y_mi.astype(int))}")
print(f"  Vertical Dominance: {np.bincount(y_vd.astype(int))}")
# Out:
# Extracting windows...
# Extracted 150 windows
# Window shape: (150, 60, 3)
# Label distributions:
#   Periodicity: [125  25]
#   Temporal Stability: [99 51]
#   Coordination: [80 70]
#   Motion Intensity: [150]
#   Vertical Dominance: [150]

# %%
print("Splitting data...")
X_train, X_test, y_p_train, y_p_test, y_t_train, y_t_test, y_c_train, y_c_test, y_mi_train, y_mi_test, y_vd_train, y_vd_test = train_test_split(
    X, y_p, y_t, y_c, y_mi, y_vd, test_size=0.25, random_state=42, stratify=None
)

print(f"Train: {len(X_train)} windows")
print(f"Test: {len(X_test)} windows")

# Show data distribution before training
print(f"\n=== DATA DISTRIBUTION BEFORE TRAINING ===")
print(f"Label distributions:")
print(f"  Periodicity: {np.bincount(y_p.astype(int), minlength=3)} (classes 0, 1, 2)")
print(f"  Temporal Stability: {np.bincount(y_t.astype(int), minlength=3)} (classes 0, 1, 2)")
print(f"  Coordination: {np.bincount(y_c.astype(int), minlength=3)} (classes 0, 1, 2)")
print(f"  Motion Intensity: {np.bincount(y_mi.astype(int), minlength=3)} (classes 0, 1, 2)")
print(f"  Vertical Dominance: {np.bincount(y_vd.astype(int), minlength=3)} (classes 0, 1, 2)")

# Check for missing classes
print(f"\n=== MISSING CLASS ANALYSIS ===")
concepts = ['Periodicity', 'Temporal Stability', 'Coordination', 'Motion Intensity', 'Vertical Dominance']
labels = [y_p, y_t, y_c, y_mi, y_vd]

for concept, label in zip(concepts, labels):
    counts = np.bincount(label.astype(int), minlength=3)
    missing_classes = [i for i, count in enumerate(counts) if count == 0]
    if missing_classes:
        print(f"  {concept}: Missing classes {missing_classes} - Only {len(counts) - len(missing_classes)} classes present")
    else:
        print(f"  {concept}: All 3 classes present ✅")
# Out:
# Splitting data...
# Train: 112 windows
# Test: 38 windows
#
# === DATA DISTRIBUTION BEFORE TRAINING ===
# Label distributions:
#   Periodicity: [125  25   0] (classes 0, 1, 2)
#   Temporal Stability: [99 51  0] (classes 0, 1, 2)
#   Coordination: [80 70  0] (classes 0, 1, 2)
#   Motion Intensity: [150   0   0] (classes 0, 1, 2)
#   Vertical Dominance: [150   0   0] (classes 0, 1, 2)
#
# === MISSING CLASS ANALYSIS ===
#   Periodicity: Missing classes [2] - Only 2 classes present
#   Temporal Stability: Missing classes [2] - Only 2 classes present
#   Coordination: Missing classes [2] - Only 2 classes present
#   Motion Intensity: Missing classes [1, 2] - Only 1 classes present
#   Vertical Dominance: Missing classes [1, 2] - Only 1 classes present

# %%
print("Augmenting training data...")
X_train_aug, y_p_train_aug, y_t_train_aug, y_c_train_aug, y_mi_train_aug, y_vd_train_aug = augment_dataset(
    X_train, y_p_train, y_t_train, y_c_train, y_mi_train, y_vd_train, factor=10
)

print(f"Original train: {len(X_train)} windows")
print(f"Augmented train: {len(X_train_aug)} windows")
print(f"Augmentation factor: {len(X_train_aug) / len(X_train):.1f}x")
# Out:
# Augmenting training data...
# Original train: 112 windows
# Augmented train: 1232 windows
# Augmentation factor: 11.0x

# %%
# Convert labels to categorical
# Discrete
y_p_train_cat = to_categorical(y_p_train_aug * 2, num_classes=3)
y_t_train_cat = to_categorical(y_t_train_aug * 2, num_classes=3)
y_c_train_cat = to_categorical(y_c_train_aug * 2, num_classes=3)

# Continous
y_mi_train_cat = y_mi_train_aug.astype(np.float32).reshape(-1, 1)
y_vd_train_cat = y_vd_train_aug.astype(np.float32).reshape(-1, 1)

# Discrete
y_p_test_cat = to_categorical(y_p_test * 2, num_classes=3)
y_t_test_cat = to_categorical(y_t_test * 2, num_classes=3)
y_c_test_cat = to_categorical(y_c_test * 2, num_classes=3)

# Continous
y_mi_test_cat = y_mi_test.astype(np.float32).reshape(-1, 1)
y_vd_test_cat = y_vd_test.astype(np.float32).reshape(-1, 1)

print("Labels converted to categorical format")
# Out:
# Labels converted to categorical format

# %%
print("Building model...")
model = build_optimized_cnn(
    input_shape=(X_train_aug.shape[1], X_train_aug.shape[2]),
    n_classes_p=3, n_classes_t=3, n_classes_c=3
)

# Compile with appropriate loss weights
model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=0.001),
        loss={
            'periodicity': 'categorical_crossentropy',
            'temporal_stability': 'categorical_crossentropy',
            'coordination': 'categorical_crossentropy',
            'motion_intensity': 'mse',
            'vertical_dominance': 'mse'
        },
        loss_weights={
            'periodicity': 1.0,
            'temporal_stability': 1.0,
            'coordination': 1.0,
            'motion_intensity': 1.0,
            'vertical_dominance': 1.0
        },
        metrics={
            'periodicity': ['accuracy'],
            'temporal_stability': ['accuracy'],
            'coordination': ['accuracy'],
            'motion_intensity': ['mse'],
            'vertical_dominance': ['mse']
        }
    )
    

print(f"Model parameters: {model.count_params():,}")
model.summary()
# Out:
# Building model...
# Model parameters: 1,259
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 60, 3)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d (Conv1D)     │ (None, 60, 16)    │        160 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 60, 16)    │         64 │ conv1d[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d       │ (None, 30, 16)    │          0 │ batch_normalizat… │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_1 (Conv1D)   │ (None, 30, 16)    │        784 │ max_pooling1d[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 30, 16)    │         64 │ conv1d_1[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 16)        │          0 │ batch_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 16)        │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ periodicity (Dense) │ (None, 3)         │         51 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ temporal_stability  │ (None, 3)         │         51 │ dropout[0][0]     │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ coordination        │ (None, 3)         │         51 │ dropout[0][0]     │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ motion_intensity    │ (None, 1)         │         17 │ dropout[0][0]     │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ vertical_dominance  │ (None, 1)         │         17 │ dropout[0][0]     │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,259 (4.92 KB)
#  Trainable params: 1,195 (4.67 KB)
#  Non-trainable params: 64 (256.00 B)

# %%
print("Training model...")
history = model.fit(
    X_train_aug,
    [y_p_train_cat, y_t_train_cat, y_c_train_cat, y_mi_train_cat, y_vd_train_cat],
    validation_data=(X_test, [y_p_test_cat, y_t_test_cat, y_c_test_cat, y_mi_test_cat, y_vd_test_cat]),
    epochs=200,
    batch_size=32,
    verbose=1,
    callbacks=[
        keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True),
        keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=5)
    ]
)

print("Training completed!")
# Out:
# Training model...
# Epoch 1/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - coordination_accuracy: 0.4115 - coordination_loss: 1.0903 - loss: 4.5061 - motion_intensity_loss: 0.7313 - motion_intensity_mse: 0.7380 - periodicity_accuracy: 0.3945 - periodicity_loss: 1.1558 - temporal_stability_accuracy: 0.4334 - temporal_stability_loss: 1.1364 - vertical_dominance_loss: 0.3788 - vertical_dominance_mse: 0.3810 - val_coordination_accuracy: 0.5263 - val_coordination_loss: 1.1528 - val_loss: 4.2588 - val_motion_intensity_loss: 0.5481 - val_motion_intensity_mse: 0.4217 - val_periodicity_accuracy: 0.2105 - val_periodicity_loss: 1.3037 - val_temporal_stability_accuracy: 0.4211 - val_temporal_stability_loss: 1.0439 - val_vertical_dominance_loss: 0.1095 - val_vertical_dominance_mse: 0.1064 - learning_rate: 0.0010
# Epoch 2/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - coordination_accuracy: 0.5641 - coordination_loss: 0.9264 - loss: 3.5713 - motion_intensity_loss: 0.4757 - motion_intensity_mse: 0.4770 - periodicity_accuracy: 0.5219 - periodicity_loss: 0.9868 - temporal_stability_accuracy: 0.6088 - temporal_stability_loss: 0.9350 - vertical_dominance_loss: 0.2456 - vertical_dominance_mse: 0.2441 - val_coordination_accuracy: 0.6053 - val_coordination_loss: 0.9196 - val_loss: 3.1431 - val_motion_intensity_loss: 0.1322 - val_motion_intensity_mse: 0.1157 - val_periodicity_accuracy: 0.4737 - val_periodicity_loss: 0.9466 - val_temporal_stability_accuracy: 0.6842 - val_temporal_stability_loss: 0.8595 - val_vertical_dominance_loss: 0.0278 - val_vertical_dominance_mse: 0.0347 - learning_rate: 0.0010
# Epoch 3/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - coordination_accuracy: 0.6096 - coordination_loss: 0.8780 - loss: 3.0800 - motion_intensity_loss: 0.2917 - motion_intensity_mse: 0.2916 - periodicity_accuracy: 0.5739 - periodicity_loss: 0.8990 - temporal_stability_accuracy: 0.7216 - temporal_stability_loss: 0.8212 - vertical_dominance_loss: 0.1866 - vertical_dominance_mse: 0.1871 - val_coordination_accuracy: 0.6579 - val_coordination_loss: 0.8423 - val_loss: 2.8361 - val_motion_intensity_loss: 0.0644 - val_motion_intensity_mse: 0.0606 - val_periodicity_accuracy: 0.6579 - val_periodicity_loss: 0.8007 - val_temporal_stability_accuracy: 0.7105 - val_temporal_stability_loss: 0.7839 - val_vertical_dominance_loss: 0.0326 - val_vertical_dominance_mse: 0.0391 - learning_rate: 0.0010
# Epoch 4/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - coordination_accuracy: 0.6599 - coordination_loss: 0.8277 - loss: 2.8856 - motion_intensity_loss: 0.2613 - motion_intensity_mse: 0.2591 - periodicity_accuracy: 0.5820 - periodicity_loss: 0.8725 - temporal_stability_accuracy: 0.7427 - temporal_stability_loss: 0.7769 - vertical_dominance_loss: 0.1457 - vertical_dominance_mse: 0.1460 - val_coordination_accuracy: 0.6579 - val_coordination_loss: 0.7837 - val_loss: 2.5973 - val_motion_intensity_loss: 0.0390 - val_motion_intensity_mse: 0.0425 - val_periodicity_accuracy: 0.6842 - val_periodicity_loss: 0.6828 - val_temporal_stability_accuracy: 0.6842 - val_temporal_stability_loss: 0.7298 - val_vertical_dominance_loss: 0.0201 - val_vertical_dominance_mse: 0.0222 - learning_rate: 0.0010
# Epoch 5/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - coordination_accuracy: 0.7078 - coordination_loss: 0.7850 - loss: 2.6403 - motion_intensity_loss: 0.1989 - motion_intensity_mse: 0.1962 - periodicity_accuracy: 0.5974 - periodicity_loss: 0.8147 - temporal_stability_accuracy: 0.7727 - temporal_stability_loss: 0.7221 - vertical_dominance_loss: 0.1204 - vertical_dominance_mse: 0.1208 - val_coordination_accuracy: 0.7105 - val_coordination_loss: 0.7259 - val_loss: 2.4128 - val_motion_intensity_loss: 0.0423 - val_motion_intensity_mse: 0.0470 - val_periodicity_accuracy: 0.7895 - val_periodicity_loss: 0.5969 - val_temporal_stability_accuracy: 0.7105 - val_temporal_stability_loss: 0.6698 - val_vertical_dominance_loss: 0.0169 - val_vertical_dominance_mse: 0.0190 - learning_rate: 0.0010
# Epoch 6/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - coordination_accuracy: 0.7248 - coordination_loss: 0.7464 - loss: 2.5043 - motion_intensity_loss: 0.1843 - motion_intensity_mse: 0.1845 - periodicity_accuracy: 0.6412 - periodicity_loss: 0.7890 - temporal_stability_accuracy: 0.7987 - temporal_stability_loss: 0.6728 - vertical_dominance_loss: 0.1102 - vertical_dominance_mse: 0.1098 - val_coordination_accuracy: 0.7105 - val_coordination_loss: 0.6772 - val_loss: 2.3057 - val_motion_intensity_loss: 0.0452 - val_motion_intensity_mse: 0.0495 - val_periodicity_accuracy: 0.7632 - val_periodicity_loss: 0.5586 - val_temporal_stability_accuracy: 0.7105 - val_temporal_stability_loss: 0.6234 - val_vertical_dominance_loss: 0.0221 - val_vertical_dominance_mse: 0.0239 - learning_rate: 0.0010
# Epoch 7/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - coordination_accuracy: 0.7256 - coordination_loss: 0.7193 - loss: 2.3876 - motion_intensity_loss: 0.1618 - motion_intensity_mse: 0.1632 - periodicity_accuracy: 0.6372 - periodicity_loss: 0.7715 - temporal_stability_accuracy: 0.8060 - temporal_stability_loss: 0.6377 - vertical_dominance_loss: 0.0980 - vertical_dominance_mse: 0.0978 - val_coordination_accuracy: 0.7105 - val_coordination_loss: 0.6571 - val_loss: 2.2447 - val_motion_intensity_loss: 0.0501 - val_motion_intensity_mse: 0.0510 - val_periodicity_accuracy: 0.7368 - val_periodicity_loss: 0.5342 - val_temporal_stability_accuracy: 0.7105 - val_temporal_stability_loss: 0.5945 - val_vertical_dominance_loss: 0.0216 - val_vertical_dominance_mse: 0.0251 - learning_rate: 0.0010
# Epoch 8/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - coordination_accuracy: 0.7476 - coordination_loss: 0.6876 - loss: 2.2599 - motion_intensity_loss: 0.1628 - motion_intensity_mse: 0.1619 - periodicity_accuracy: 0.6607 - periodicity_loss: 0.7298 - temporal_stability_accuracy: 0.8231 - temporal_stability_loss: 0.5897 - vertical_dominance_loss: 0.0923 - vertical_dominance_mse: 0.0920 - val_coordination_accuracy: 0.6842 - val_coordination_loss: 0.6539 - val_loss: 2.1977 - val_motion_intensity_loss: 0.0500 - val_motion_intensity_mse: 0.0499 - val_periodicity_accuracy: 0.7368 - val_periodicity_loss: 0.5201 - val_temporal_stability_accuracy: 0.7105 - val_temporal_stability_loss: 0.5663 - val_vertical_dominance_loss: 0.0179 - val_vertical_dominance_mse: 0.0197 - learning_rate: 0.0010
# Epoch 9/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - coordination_accuracy: 0.7411 - coordination_loss: 0.6904 - loss: 2.2379 - motion_intensity_loss: 0.1524 - motion_intensity_mse: 0.1507 - periodicity_accuracy: 0.6534 - periodicity_loss: 0.7255 - temporal_stability_accuracy: 0.8166 - temporal_stability_loss: 0.5996 - vertical_dominance_loss: 0.0732 - vertical_dominance_mse: 0.0736 - val_coordination_accuracy: 0.7105 - val_coordination_loss: 0.6194 - val_loss: 2.1459 - val_motion_intensity_loss: 0.0427 - val_motion_intensity_mse: 0.0408 - val_periodicity_accuracy: 0.7105 - val_periodicity_loss: 0.5168 - val_temporal_stability_accuracy: 0.7105 - val_temporal_stability_loss: 0.5451 - val_vertical_dominance_loss: 0.0177 - val_vertical_dominance_mse: 0.0167 - learning_rate: 0.0010
# Epoch 10/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - coordination_accuracy: 0.7532 - coordination_loss: 0.6490 - loss: 2.0881 - motion_intensity_loss: 0.1305 - motion_intensity_mse: 0.1295 - periodicity_accuracy: 0.6713 - periodicity_loss: 0.6935 - temporal_stability_accuracy: 0.8295 - temporal_stability_loss: 0.5449 - vertical_dominance_loss: 0.0688 - vertical_dominance_mse: 0.0689 - val_coordination_accuracy: 0.7105 - val_coordination_loss: 0.6050 - val_loss: 2.1113 - val_motion_intensity_loss: 0.0420 - val_motion_intensity_mse: 0.0392 - val_periodicity_accuracy: 0.7632 - val_periodicity_loss: 0.5011 - val_temporal_stability_accuracy: 0.7105 - val_temporal_stability_loss: 0.5302 - val_vertical_dominance_loss: 0.0148 - val_vertical_dominance_mse: 0.0148 - learning_rate: 0.0010
# Epoch 11/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - coordination_accuracy: 0.7484 - coordination_loss: 0.6370 - loss: 2.0261 - motion_intensity_loss: 0.1213 - motion_intensity_mse: 0.1217 - periodicity_accuracy: 0.6981 - periodicity_loss: 0.6667 - temporal_stability_accuracy: 0.8320 - temporal_stability_loss: 0.5400 - vertical_dominance_loss: 0.0606 - vertical_dominance_mse: 0.0610 - val_coordination_accuracy: 0.7105 - val_coordination_loss: 0.6042 - val_loss: 2.1037 - val_motion_intensity_loss: 0.0461 - val_motion_intensity_mse: 0.0416 - val_periodicity_accuracy: 0.7368 - val_periodicity_loss: 0.5113 - val_temporal_stability_accuracy: 0.7105 - val_temporal_stability_loss: 0.5272 - val_vertical_dominance_loss: 0.0134 - val_vertical_dominance_mse: 0.0137 - learning_rate: 0.0010
# Epoch 12/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - coordination_accuracy: 0.7476 - coordination_loss: 0.6430 - loss: 2.0073 - motion_intensity_loss: 0.1007 - motion_intensity_mse: 0.1005 - periodicity_accuracy: 0.6867 - periodicity_loss: 0.6760 - temporal_stability_accuracy: 0.8344 - temporal_stability_loss: 0.5333 - vertical_dominance_loss: 0.0574 - vertical_dominance_mse: 0.0571 - val_coordination_accuracy: 0.7105 - val_coordination_loss: 0.6048 - val_loss: 2.1204 - val_motion_intensity_loss: 0.0483 - val_motion_intensity_mse: 0.0406 - val_periodicity_accuracy: 0.7105 - val_periodicity_loss: 0.5106 - val_temporal_stability_accuracy: 0.7105 - val_temporal_stability_loss: 0.5043 - val_vertical_dominance_loss: 0.0143 - val_vertical_dominance_mse: 0.0144 - learning_rate: 0.0010
# Epoch 13/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - coordination_accuracy: 0.7679 - coordination_loss: 0.6180 - loss: 1.9100 - motion_intensity_loss: 0.0884 - motion_intensity_mse: 0.0891 - periodicity_accuracy: 0.7208 - periodicity_loss: 0.6516 - temporal_stability_accuracy: 0.8450 - temporal_stability_loss: 0.5061 - vertical_dominance_loss: 0.0499 - vertical_dominance_mse: 0.0499 - val_coordination_accuracy: 0.7105 - val_coordination_loss: 0.6029 - val_loss: 2.0847 - val_motion_intensity_loss: 0.0503 - val_motion_intensity_mse: 0.0396 - val_periodicity_accuracy: 0.7368 - val_periodicity_loss: 0.5022 - val_temporal_stability_accuracy: 0.7105 - val_temporal_stability_loss: 0.4922 - val_vertical_dominance_loss: 0.0131 - val_vertical_dominance_mse: 0.0128 - learning_rate: 0.0010
# Epoch 14/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - coordination_accuracy: 0.7808 - coordination_loss: 0.5859 - loss: 1.8218 - motion_intensity_loss: 0.0813 - motion_intensity_mse: 0.0815 - periodicity_accuracy: 0.7248 - periodicity_loss: 0.6256 - temporal_stability_accuracy: 0.8312 - temporal_stability_loss: 0.4818 - vertical_dominance_loss: 0.0427 - vertical_dominance_mse: 0.0427 - val_coordination_accuracy: 0.7105 - val_coordination_loss: 0.5894 - val_loss: 2.0835 - val_motion_intensity_loss: 0.0444 - val_motion_intensity_mse: 0.0341 - val_periodicity_accuracy: 0.7105 - val_periodicity_loss: 0.5101 - val_temporal_stability_accuracy: 0.7105 - val_temporal_stability_loss: 0.4797 - val_vertical_dominance_loss: 0.0112 - val_vertical_dominance_mse: 0.0117 - learning_rate: 0.0010
# Epoch 15/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - coordination_accuracy: 0.7873 - coordination_loss: 0.5824 - loss: 1.7983 - motion_intensity_loss: 0.0727 - motion_intensity_mse: 0.0728 - periodicity_accuracy: 0.7102 - periodicity_loss: 0.6335 - temporal_stability_accuracy: 0.8474 - temporal_stability_loss: 0.4657 - vertical_dominance_loss: 0.0414 - vertical_dominance_mse: 0.0413 - val_coordination_accuracy: 0.7105 - val_coordination_loss: 0.5805 - val_loss: 2.0791 - val_motion_intensity_loss: 0.0393 - val_motion_intensity_mse: 0.0273 - val_periodicity_accuracy: 0.6842 - val_periodicity_loss: 0.5306 - val_temporal_stability_accuracy: 0.7368 - val_temporal_stability_loss: 0.4685 - val_vertical_dominance_loss: 0.0119 - val_vertical_dominance_mse: 0.0117 - learning_rate: 0.0010
# Epoch 16/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - coordination_accuracy: 0.7833 - coordination_loss: 0.5607 - loss: 1.7217 - motion_intensity_loss: 0.0647 - motion_intensity_mse: 0.0644 - periodicity_accuracy: 0.7159 - periodicity_loss: 0.6231 - temporal_stability_accuracy: 0.8515 - temporal_stability_loss: 0.4396 - vertical_dominance_loss: 0.0338 - vertical_dominance_mse: 0.0339 - val_coordination_accuracy: 0.7105 - val_coordination_loss: 0.5602 - val_loss: 2.0439 - val_motion_intensity_loss: 0.0324 - val_motion_intensity_mse: 0.0209 - val_periodicity_accuracy: 0.7105 - val_periodicity_loss: 0.5295 - val_temporal_stability_accuracy: 0.7105 - val_temporal_stability_loss: 0.4691 - val_vertical_dominance_loss: 0.0103 - val_vertical_dominance_mse: 0.0112 - learning_rate: 0.0010
# Epoch 17/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - coordination_accuracy: 0.7833 - coordination_loss: 0.5650 - loss: 1.6917 - motion_intensity_loss: 0.0629 - motion_intensity_mse: 0.0632 - periodicity_accuracy: 0.7248 - periodicity_loss: 0.6025 - temporal_stability_accuracy: 0.8669 - temporal_stability_loss: 0.4248 - vertical_dominance_loss: 0.0328 - vertical_dominance_mse: 0.0329 - val_coordination_accuracy: 0.7105 - val_coordination_loss: 0.5742 - val_loss: 2.0964 - val_motion_intensity_loss: 0.0284 - val_motion_intensity_mse: 0.0182 - val_periodicity_accuracy: 0.6842 - val_periodicity_loss: 0.5152 - val_temporal_stability_accuracy: 0.7105 - val_temporal_stability_loss: 0.4757 - val_vertical_dominance_loss: 0.0102 - val_vertical_dominance_mse: 0.0112 - learning_rate: 0.0010
# Epoch 18/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - coordination_accuracy: 0.8011 - coordination_loss: 0.5346 - loss: 1.6381 - motion_intensity_loss: 0.0579 - motion_intensity_mse: 0.0579 - periodicity_accuracy: 0.7378 - periodicity_loss: 0.5934 - temporal_stability_accuracy: 0.8588 - temporal_stability_loss: 0.4192 - vertical_dominance_loss: 0.0286 - vertical_dominance_mse: 0.0288 - val_coordination_accuracy: 0.7105 - val_coordination_loss: 0.5757 - val_loss: 2.0558 - val_motion_intensity_loss: 0.0281 - val_motion_intensity_mse: 0.0186 - val_periodicity_accuracy: 0.6842 - val_periodicity_loss: 0.5337 - val_temporal_stability_accuracy: 0.7105 - val_temporal_stability_loss: 0.4501 - val_vertical_dominance_loss: 0.0093 - val_vertical_dominance_mse: 0.0107 - learning_rate: 0.0010
# Epoch 19/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - coordination_accuracy: 0.8011 - coordination_loss: 0.5505 - loss: 1.6457 - motion_intensity_loss: 0.0491 - motion_intensity_mse: 0.0495 - periodicity_accuracy: 0.7313 - periodicity_loss: 0.6126 - temporal_stability_accuracy: 0.8531 - temporal_stability_loss: 0.4136 - vertical_dominance_loss: 0.0266 - vertical_dominance_mse: 0.0267 - val_coordination_accuracy: 0.7105 - val_coordination_loss: 0.5604 - val_loss: 2.0599 - val_motion_intensity_loss: 0.0259 - val_motion_intensity_mse: 0.0154 - val_periodicity_accuracy: 0.6842 - val_periodicity_loss: 0.5404 - val_temporal_stability_accuracy: 0.7368 - val_temporal_stability_loss: 0.4535 - val_vertical_dominance_loss: 0.0088 - val_vertical_dominance_mse: 0.0102 - learning_rate: 0.0010
# Epoch 20/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - coordination_accuracy: 0.8109 - coordination_loss: 0.5225 - loss: 1.5918 - motion_intensity_loss: 0.0440 - motion_intensity_mse: 0.0438 - periodicity_accuracy: 0.7378 - periodicity_loss: 0.5886 - temporal_stability_accuracy: 0.8580 - temporal_stability_loss: 0.4144 - vertical_dominance_loss: 0.0242 - vertical_dominance_mse: 0.0243 - val_coordination_accuracy: 0.6842 - val_coordination_loss: 0.5992 - val_loss: 2.0560 - val_motion_intensity_loss: 0.0253 - val_motion_intensity_mse: 0.0159 - val_periodicity_accuracy: 0.7105 - val_periodicity_loss: 0.5308 - val_temporal_stability_accuracy: 0.7105 - val_temporal_stability_loss: 0.4446 - val_vertical_dominance_loss: 0.0085 - val_vertical_dominance_mse: 0.0098 - learning_rate: 0.0010
# Epoch 21/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - coordination_accuracy: 0.8166 - coordination_loss: 0.5027 - loss: 1.5351 - motion_intensity_loss: 0.0355 - motion_intensity_mse: 0.0356 - periodicity_accuracy: 0.7427 - periodicity_loss: 0.5726 - temporal_stability_accuracy: 0.8571 - temporal_stability_loss: 0.4022 - vertical_dominance_loss: 0.0213 - vertical_dominance_mse: 0.0212 - val_coordination_accuracy: 0.7105 - val_coordination_loss: 0.5904 - val_loss: 2.0278 - val_motion_intensity_loss: 0.0238 - val_motion_intensity_mse: 0.0135 - val_periodicity_accuracy: 0.7105 - val_periodicity_loss: 0.5324 - val_temporal_stability_accuracy: 0.7105 - val_temporal_stability_loss: 0.4344 - val_vertical_dominance_loss: 0.0084 - val_vertical_dominance_mse: 0.0101 - learning_rate: 0.0010
# Epoch 22/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - coordination_accuracy: 0.8068 - coordination_loss: 0.5055 - loss: 1.5202 - motion_intensity_loss: 0.0339 - motion_intensity_mse: 0.0340 - periodicity_accuracy: 0.7484 - periodicity_loss: 0.5732 - temporal_stability_accuracy: 0.8677 - temporal_stability_loss: 0.3848 - vertical_dominance_loss: 0.0185 - vertical_dominance_mse: 0.0186 - val_coordination_accuracy: 0.7105 - val_coordination_loss: 0.5697 - val_loss: 2.1038 - val_motion_intensity_loss: 0.0169 - val_motion_intensity_mse: 0.0110 - val_periodicity_accuracy: 0.6579 - val_periodicity_loss: 0.5539 - val_temporal_stability_accuracy: 0.7368 - val_temporal_stability_loss: 0.4394 - val_vertical_dominance_loss: 0.0085 - val_vertical_dominance_mse: 0.0091 - learning_rate: 0.0010
# Epoch 23/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - coordination_accuracy: 0.8076 - coordination_loss: 0.5086 - loss: 1.5105 - motion_intensity_loss: 0.0292 - motion_intensity_mse: 0.0294 - periodicity_accuracy: 0.7492 - periodicity_loss: 0.5654 - temporal_stability_accuracy: 0.8661 - temporal_stability_loss: 0.3955 - vertical_dominance_loss: 0.0171 - vertical_dominance_mse: 0.0171 - val_coordination_accuracy: 0.7105 - val_coordination_loss: 0.5982 - val_loss: 2.0848 - val_motion_intensity_loss: 0.0172 - val_motion_intensity_mse: 0.0106 - val_periodicity_accuracy: 0.7105 - val_periodicity_loss: 0.5439 - val_temporal_stability_accuracy: 0.7105 - val_temporal_stability_loss: 0.4400 - val_vertical_dominance_loss: 0.0079 - val_vertical_dominance_mse: 0.0085 - learning_rate: 0.0010
# Epoch 24/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - coordination_accuracy: 0.8271 - coordination_loss: 0.4773 - loss: 1.4806 - motion_intensity_loss: 0.0277 - motion_intensity_mse: 0.0277 - periodicity_accuracy: 0.7532 - periodicity_loss: 0.5823 - temporal_stability_accuracy: 0.8750 - temporal_stability_loss: 0.3786 - vertical_dominance_loss: 0.0146 - vertical_dominance_mse: 0.0144 - val_coordination_accuracy: 0.7105 - val_coordination_loss: 0.5988 - val_loss: 2.1847 - val_motion_intensity_loss: 0.0165 - val_motion_intensity_mse: 0.0096 - val_periodicity_accuracy: 0.6842 - val_periodicity_loss: 0.5316 - val_temporal_stability_accuracy: 0.6842 - val_temporal_stability_loss: 0.4656 - val_vertical_dominance_loss: 0.0079 - val_vertical_dominance_mse: 0.0091 - learning_rate: 0.0010
# Epoch 25/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - coordination_accuracy: 0.8182 - coordination_loss: 0.4628 - loss: 1.4231 - motion_intensity_loss: 0.0252 - motion_intensity_mse: 0.0253 - periodicity_accuracy: 0.7516 - periodicity_loss: 0.5516 - temporal_stability_accuracy: 0.8636 - temporal_stability_loss: 0.3684 - vertical_dominance_loss: 0.0137 - vertical_dominance_mse: 0.0138 - val_coordination_accuracy: 0.7105 - val_coordination_loss: 0.5578 - val_loss: 2.0772 - val_motion_intensity_loss: 0.0138 - val_motion_intensity_mse: 0.0077 - val_periodicity_accuracy: 0.7105 - val_periodicity_loss: 0.5485 - val_temporal_stability_accuracy: 0.7105 - val_temporal_stability_loss: 0.4498 - val_vertical_dominance_loss: 0.0061 - val_vertical_dominance_mse: 0.0067 - learning_rate: 0.0010
# Epoch 26/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - coordination_accuracy: 0.8198 - coordination_loss: 0.4669 - loss: 1.3953 - motion_intensity_loss: 0.0212 - motion_intensity_mse: 0.0213 - periodicity_accuracy: 0.7719 - periodicity_loss: 0.5423 - temporal_stability_accuracy: 0.8742 - temporal_stability_loss: 0.3499 - vertical_dominance_loss: 0.0120 - vertical_dominance_mse: 0.0121 - val_coordination_accuracy: 0.7105 - val_coordination_loss: 0.5957 - val_loss: 2.1702 - val_motion_intensity_loss: 0.0118 - val_motion_intensity_mse: 0.0062 - val_periodicity_accuracy: 0.6842 - val_periodicity_loss: 0.5417 - val_temporal_stability_accuracy: 0.7105 - val_temporal_stability_loss: 0.4516 - val_vertical_dominance_loss: 0.0066 - val_vertical_dominance_mse: 0.0077 - learning_rate: 0.0010
# Epoch 27/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - coordination_accuracy: 0.8166 - coordination_loss: 0.4733 - loss: 1.3715 - motion_intensity_loss: 0.0175 - motion_intensity_mse: 0.0173 - periodicity_accuracy: 0.7865 - periodicity_loss: 0.5248 - temporal_stability_accuracy: 0.8839 - temporal_stability_loss: 0.3414 - vertical_dominance_loss: 0.0109 - vertical_dominance_mse: 0.0109 - val_coordination_accuracy: 0.7105 - val_coordination_loss: 0.5751 - val_loss: 2.1604 - val_motion_intensity_loss: 0.0128 - val_motion_intensity_mse: 0.0071 - val_periodicity_accuracy: 0.6579 - val_periodicity_loss: 0.5816 - val_temporal_stability_accuracy: 0.7105 - val_temporal_stability_loss: 0.4371 - val_vertical_dominance_loss: 0.0070 - val_vertical_dominance_mse: 0.0084 - learning_rate: 5.0000e-04
# Epoch 28/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - coordination_accuracy: 0.8385 - coordination_loss: 0.4456 - loss: 1.3514 - motion_intensity_loss: 0.0159 - motion_intensity_mse: 0.0158 - periodicity_accuracy: 0.7792 - periodicity_loss: 0.5342 - temporal_stability_accuracy: 0.8718 - temporal_stability_loss: 0.3450 - vertical_dominance_loss: 0.0100 - vertical_dominance_mse: 0.0100 - val_coordination_accuracy: 0.7105 - val_coordination_loss: 0.5769 - val_loss: 2.1449 - val_motion_intensity_loss: 0.0130 - val_motion_intensity_mse: 0.0075 - val_periodicity_accuracy: 0.6842 - val_periodicity_loss: 0.5677 - val_temporal_stability_accuracy: 0.7105 - val_temporal_stability_loss: 0.4372 - val_vertical_dominance_loss: 0.0063 - val_vertical_dominance_mse: 0.0072 - learning_rate: 5.0000e-04
# Epoch 29/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - coordination_accuracy: 0.8409 - coordination_loss: 0.4337 - loss: 1.3313 - motion_intensity_loss: 0.0164 - motion_intensity_mse: 0.0164 - periodicity_accuracy: 0.7695 - periodicity_loss: 0.5281 - temporal_stability_accuracy: 0.8815 - temporal_stability_loss: 0.3439 - vertical_dominance_loss: 0.0092 - vertical_dominance_mse: 0.0092 - val_coordination_accuracy: 0.7105 - val_coordination_loss: 0.5768 - val_loss: 2.1358 - val_motion_intensity_loss: 0.0122 - val_motion_intensity_mse: 0.0066 - val_periodicity_accuracy: 0.6842 - val_periodicity_loss: 0.5693 - val_temporal_stability_accuracy: 0.7105 - val_temporal_stability_loss: 0.4326 - val_vertical_dominance_loss: 0.0065 - val_vertical_dominance_mse: 0.0075 - learning_rate: 5.0000e-04
# Epoch 30/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - coordination_accuracy: 0.8344 - coordination_loss: 0.4481 - loss: 1.3055 - motion_intensity_loss: 0.0141 - motion_intensity_mse: 0.0142 - periodicity_accuracy: 0.7857 - periodicity_loss: 0.5142 - temporal_stability_accuracy: 0.8937 - temporal_stability_loss: 0.3197 - vertical_dominance_loss: 0.0100 - vertical_dominance_mse: 0.0100 - val_coordination_accuracy: 0.7105 - val_coordination_loss: 0.5959 - val_loss: 2.1747 - val_motion_intensity_loss: 0.0121 - val_motion_intensity_mse: 0.0060 - val_periodicity_accuracy: 0.6579 - val_periodicity_loss: 0.5755 - val_temporal_stability_accuracy: 0.7368 - val_temporal_stability_loss: 0.4351 - val_vertical_dominance_loss: 0.0063 - val_vertical_dominance_mse: 0.0075 - learning_rate: 5.0000e-04
# Epoch 31/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - coordination_accuracy: 0.8417 - coordination_loss: 0.4314 - loss: 1.2860 - motion_intensity_loss: 0.0149 - motion_intensity_mse: 0.0150 - periodicity_accuracy: 0.8011 - periodicity_loss: 0.4921 - temporal_stability_accuracy: 0.8839 - temporal_stability_loss: 0.3399 - vertical_dominance_loss: 0.0086 - vertical_dominance_mse: 0.0086 - val_coordination_accuracy: 0.7105 - val_coordination_loss: 0.6025 - val_loss: 2.1596 - val_motion_intensity_loss: 0.0112 - val_motion_intensity_mse: 0.0060 - val_periodicity_accuracy: 0.6842 - val_periodicity_loss: 0.5646 - val_temporal_stability_accuracy: 0.7105 - val_temporal_stability_loss: 0.4286 - val_vertical_dominance_loss: 0.0059 - val_vertical_dominance_mse: 0.0070 - learning_rate: 5.0000e-04
# Training completed!

# %%
def calculate_auroc_multi_output(y_true_categorical, y_pred_proba, concept_name, num_classes):
    """
    Calculate AUROC for multi-output CNN concepts
    
    Args:
        y_true_categorical: True labels in categorical format
        y_pred_proba: Predicted probabilities from model
        concept_name: Name of the concept (for discrete concepts only)
        num_classes: Number of classes for this concept
    
    Returns:
        AUROC score
    """
    # Convert categorical to integer labels
    y_true = np.argmax(y_true_categorical, axis=1)
    
    # For binary classification (2 classes)
    if num_classes == 2:
        # Use the probability of the positive class
        y_scores = y_pred_proba[:, 1]
        return roc_auc_score(y_true, y_scores)
    else:
        # Binarize the labels for multi-class AUROC calculation
        y_true_bin = label_binarize(y_true, classes=range(num_classes))
        
        if y_true_bin.shape[1] == 1:
            # Binary case
            return roc_auc_score(y_true_bin, y_pred_proba[:, 1])
        else:
            # Multi-class case
            return roc_auc_score(y_true_bin, y_pred_proba, multi_class='ovr', average='macro')

# %%
y_test_map = {
    'periodicity': y_p_test_cat,
    'temporal_stability': y_t_test_cat,
    'coordination': y_c_test_cat,
    'motion_intensity': y_mi_test_cat,
    'vertical_dominance': y_vd_test_cat,
}

# Evaluate model
print("Evaluating model...")
results = model.evaluate(X_test, list(y_test_map.values()), verbose=0)


predictions = model.predict(X_test, verbose=0)
periodicity_pred = np.argmax(predictions[0], axis=1)
temporal_stability_pred = np.argmax(predictions[1], axis=1)
coordination_pred = np.argmax(predictions[2], axis=1)
motion_intensity_pred = np.argmax(predictions[3], axis=1)
vertical_dominance_pred = np.argmax(predictions[4], axis=1)

periodicity_acc = accuracy_score(np.argmax(y_p_test_cat, axis=1), periodicity_pred)
temporal_stability_acc = accuracy_score(np.argmax(y_t_test_cat, axis=1), temporal_stability_pred)
coordination_acc = accuracy_score(np.argmax(y_c_test_cat, axis=1), coordination_pred)
motion_intensity_acc = accuracy_score(np.argmax(y_mi_test_cat, axis=1), motion_intensity_pred)
vertical_dominance_acc = accuracy_score(np.argmax(y_vd_test_cat, axis=1), vertical_dominance_pred)

periodicity_auroc = calculate_auroc_multi_output(y_p_test_cat, predictions[0], 'periodicity', 3)
temporal_stability_auroc = calculate_auroc_multi_output(y_t_test_cat, predictions[1], 'temporal_stability', 3)
coordination_auroc = calculate_auroc_multi_output(y_c_test_cat, predictions[2], 'coordination', 3)

from sklearn.metrics import r2_score
motion_intensity_r2 = r2_score(y_mi_test_cat.flatten(), predictions[3].flatten())
vertical_dominance_r2 = r2_score(y_vd_test_cat.flatten(), predictions[4].flatten())

overall_acc = (periodicity_acc + temporal_stability_acc + coordination_acc + motion_intensity_acc + vertical_dominance_acc) / len(concept_columns)

auroc_scores = [periodicity_auroc, temporal_stability_auroc, coordination_auroc]
valid_auroc_scores = [score for score in auroc_scores if not np.isnan(score)]
overall_auroc = np.mean(valid_auroc_scores) if valid_auroc_scores else 0.5

print(f"\n=== RESULTS ===")
print(f"\n--- Classification Concepts (Discrete) ---")
print(f"Periodicity - Accuracy: {periodicity_acc:.4f}, AUROC: {periodicity_auroc:.4f}")
print(f"Temporal Stability - Accuracy: {temporal_stability_acc:.4f}, AUROC: {temporal_stability_auroc:.4f}")
print(f"Coordination - Accuracy: {coordination_acc:.4f}, AUROC: {coordination_auroc:.4f}")

print(f"\n--- Regression Concepts (Continuous) ---")
print(f"Motion Intensity - Accuracy: {motion_intensity_acc:.4f}, R²: {motion_intensity_r2:.4f}")
print(f"Vertical Dominance - Accuracy: {vertical_dominance_acc:.4f}, R²: {vertical_dominance_r2:.4f}")

print(f"\n--- Overall Performance ---")
print(f"Overall Average Accuracy: {overall_acc*100:.1f}%")
print(f"Overall Average AUROC (classification concepts): {overall_auroc:.4f}")
# Out:
# Evaluating model...
#
# === RESULTS ===
#
# --- Classification Concepts (Discrete) ---
# Periodicity - Accuracy: 0.7105, AUROC: 0.9063
# Temporal Stability - Accuracy: 0.7105, AUROC: 0.8406
# Coordination - Accuracy: 0.7105, AUROC: 0.7967
#
# --- Regression Concepts (Continuous) ---
# Motion Intensity - Accuracy: 1.0000, R²: -5.5360
# Vertical Dominance - Accuracy: 1.0000, R²: -0.2719
#
# --- Overall Performance ---
# Overall Average Accuracy: 82.6%
# Overall Average AUROC (classification concepts): 0.8479

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 8))

for i, concept in enumerate(discrete_concepts):
    row, col = i // 2, i % 2
    axes[row, col].plot(history.history[f'{concept}_accuracy'], label=f'{concept.title()} Accuracy')
    axes[row, col].plot(history.history[f'val_{concept}_accuracy'], label=f'Val {concept.title()} Accuracy')
    axes[row, col].set_title(f'{concept.title()} Accuracy')
    axes[row, col].set_xlabel('Epoch')
    axes[row, col].set_ylabel('Accuracy')
    axes[row, col].legend()
    axes[row, col].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()


fig, axes = plt.subplots(1, 2, figsize=(12, 4))

for i, concept in enumerate(continuous_concepts):
    axes[i].plot(history.history[f'{concept}_mse'], label=f'{concept.title()} MSE')
    axes[i].plot(history.history[f'val_{concept}_mse'], label=f'Val {concept.title()} MSE')
    axes[i].set_title(f'{concept.title()} MSE')
    axes[i].set_xlabel('Epoch')
    axes[i].set_ylabel('MSE')
    axes[i].legend()
    axes[i].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %%
model.save("./models/sensor_data_to_concept_model.keras")
print("Model saved to /models/sensor_data_to_concept_model.keras")
# Out:
# Model saved to /models/sensor_data_to_concept_model.keras
